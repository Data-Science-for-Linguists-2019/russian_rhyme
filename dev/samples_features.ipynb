# %% [markdown]
# # Dendrogram samples
#
# This notebook applies the methods explored in [progress_report_4.ipynb](progress_report_4.ipynb) to an assortment of poems with different properties. It begins by consolidating the run script into a function, which is then called against different samples.

# %% [markdown]
# ## Reload libraries each time, since we’re tinkering with them

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load libraries

# %%
from xml.dom import pulldom  # parse input XML
from xml.dom.minidom import Document  # construct output XML
import numpy as np
import pandas as pd
from scipy import stats
from scipy.cluster.hierarchy import dendrogram, linkage
# see https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
# %matplotlib inline
import regex as re
import json
from cyr2phon import cyr2phon  # custom package
pd.set_option('display.max_colwidth', -1) # show all text in cell, without truncation; default is 50
pd.set_option('display.max_columns', None) # show all columns; default is 20

# %% [markdown]
# ## Class and variables for parsing input XML

# %%
class Stack(list):  # keep track of open nodes while constructing XML output
    def push(self, item):
        self.append(item)

    def peek(self):  
        return self[-1]


open_elements = Stack()
WS_RE = re.compile(r'\s+')  # normalize white space in output

# %% [markdown]
# ## Function to parse the XML
#
# Returns a list of lists, with stanza number, line number, and `<line>` element for each line. We use the light-weight *xml.dom.pulldom* library to parse the input XML and *xml.dom.minidom* to construct the lines as simplified XML, removing elements we don’t care about, such as `<latin>` and `<italic>`, before serializing them to the output. (We actually do care about `<latin>`, but we are ignoring it temporarily, and we’ll return to it at a later stage in the project.)

# %%
def process(input_xml):
    poemId = ""
    stanzaNo = 0
    lineNo = 0
    inline = 0  # flag to control behavior inside and outside lines
    result = []  # array of arrays, one per line, with stanzaNo, lineNo, and serialized XML
    doc = pulldom.parse(input_xml)
    for event, node in doc:
        if event == pulldom.START_ELEMENT and node.localName == 'poem':
            poemId = node.getAttribute("opid")
        elif event == pulldom.START_ELEMENT and node.localName == 'stanza':
            stanzaNo = node.getAttribute("stanzaNo")
        elif event == pulldom.START_ELEMENT and node.localName == 'line':
            d = Document()  # each line is an output XML document
            open_elements.push(d)  # document node
            lineNo = node.getAttribute("lineNo")
            inline = 1  # we’re inside a line
            open_elements.peek().appendChild(node)  # add as child of current node in output tree
            open_elements.push(node)  # keep track of open elements
        elif event == pulldom.END_ELEMENT and node.localName == 'line':
            inline = 0  # when we finish our work here, we’ll no longer be inside a line
            open_elements.pop()  # line is finished
            # serialize XML, strip declaration, rewrite &quot; entity as character
            result.append([poemId, int(stanzaNo), int(lineNo),
                WS_RE.sub(" " ,
                open_elements.pop().toxml().replace('<?xml version="1.0" ?>', '').replace('&quot;', '"'))])
        elif event == pulldom.START_ELEMENT and node.localName == 'stress':
            open_elements.peek().appendChild(node)  # add as child of current node in output tree
            open_elements.push(node)  # keep track of open elements
        elif event == pulldom.END_ELEMENT and node.localName == 'stress':
            open_elements.pop()  # stress element is finished
        elif event == pulldom.CHARACTERS and inline:  # keep text only inside lines
            t = d.createTextNode(node.data)
            open_elements.peek().appendChild(t)
    return result

# %% [markdown]
# ## Function to extract rhyme zone from rhyme word

# %%
rhymezonepat = re.compile(r'(.?[AEIOU]$)|([AEIOU].*$)')
def remove_pretonic_segments(s: str) -> str: # removes segments in place
    try:
        return rhymezonepat.search(s).group(0)
    except: # modify this to raise a real error, instead of just reporting
        print(s)

# %% [markdown]
# ## Imports sample file, analyzes, outputs reports

# %%
def explore(filepath, ceiling=1000, ward=None):
    '''Render text and dendrograms of rhyme clustering
    
    Parameters:
        filepath (str): path to XML file with poem, required
        ceiling (int): maximum number of stanzas to return (useful for sampling long poems), 
            defaults to high value
        ward (boolean): show Ward dendrogram separately (improves legibility of long stanzas),
            defaults to None
    
    Does not return a value; all output is written directly from within the function
    '''
    
    # Read file
    with open(filepath) as f:
        data = process(f)
    df = pd.DataFrame(data, columns=["PoemId", "StanzaNo", "LineNo", "Text"])
    
    # Prepare data
    trans_vec = np.vectorize(cyr2phon.transliterate)
    df["Phonetic"] = trans_vec(df["Text"])
    df["RhymeWord"] = df["Phonetic"].str.split().str[-1] # clitics have already been joined
    df["RhymeZone"] = df["RhymeWord"].apply(remove_pretonic_segments)
    df.loc[df["RhymeZone"].isnull(), "RhymeZone"] = "Abcde" # provisional placeholder for nulls
    df["tokenized"] = [x[0] for x in df["RhymeZone"].str.
                       findall(r"(.?)([AEIOU])([^aeiou]*)([aeiou]?)([^aeiou]*)([aeiou]?)([^aeiou]*)([aeiou]?)([^aeiou]*)([aeiou]?)([^aeiou]*)([aeiou]?)([^aeiou]*)([aeiou]?)([^aeiou]*)([aeiou]?)([^aeiou]*)([aeiou]?)")]
    i = 0
    while pd.np.count_nonzero([item[i] for item in df["tokenized"]]) > 0:
#         print([item[i] for item in df["tokenized"]]) # diagnostic
        df["token" + str(i)] = [item[i] for item in df["tokenized"]]
        i += 1
    tokenheaders = df.filter(regex="^token\d").columns
    df[tokenheaders] = df[tokenheaders].replace(r'^$', "missing", regex=True) # replace empty strings with specific value; inplace doesn't work (?)
    df.filter(regex=r"StanzaNo|LineNo|RhymeWord|Text|^token\d").head() # columns we care about
#     print(df[tokenheaders])
    
    with open('features.json') as json_file:
        feature_matrix = json.load(json_file)
    feature_names = {feature for segment,features in feature_matrix.items() for feature in features}
    
    print(feature_matrix['p']['Sonorant'])
    
    for tokenheader in tokenheaders:
        for feature_name in feature_names:
            df[tokenheader + '_' + feature_name] = feature_matrix.get(tuple(df[tokenheader]), 'hi')


    #     dummy = pd.get_dummies(df, columns=df.filter(regex="^token\d").columns, drop_first=True)
#     df = df.merge(dummy, on=["PoemId", "StanzaNo", "LineNo", "Text", "Phonetic", "RhymeWord", "RhymeZone", "tokenized"])
#     df.set_index(["PoemId", "StanzaNo", "LineNo"], inplace=True)
    
    # Visualize
#     methods = ["single", "complete", "average", "weighted", "centroid", "median", "ward"]
#     stanzas = df.groupby(level=[0,1])
#     pd.set_option('display.width', 1000) # don't wrap long rows
#     for offset, (id, lines) in enumerate(stanzas):
#         if offset < ceiling:
#             print(pd.concat([lines["Text"].str.replace(r"<[^>]+?>", ""), lines[["RhymeWord", "RhymeZone"]]], axis=1)) # diagnostic
#             data = lines.copy().filter(regex=r"^token\d_") # only one-hot features
#             missing = data.filter(regex=r"missing$")
#             missing = missing * 0.2 # reduce weight of missing values
#             labelList = list(range(1, len(lines)+1)) # labels are line numbers within stanza
#             data.loc[:,"LineNo"] = [n / (len(labelList) * 2) for n in labelList] # scale to avoid tyranny of proximity, currently 0 <= n <= 0.5
#             plt.figure(figsize=(20, 2))
#             for n, m in enumerate(methods):
#                 linked = linkage(data, method=m)
#                 m_c, m_coph_dist = cophenet(linked, pdist(data))
#                 plt.subplot(1, 7, n + 1)
#                 plt.title(m + ": " + str(round(m_c, 3)))
#                 dendrogram(linked, labels=labelList)
#             plt.show()
#             if ward:
#                 linked = linkage(data, method="ward")
#                 labelList=list(range(1,len(lines)+1))
#                 c, coph_dist = cophenet(linked, pdist(data))
#                 plt.figure(figsize=(20, 10))
#                 plt.title("Ward: " + str(c))
#                 dendrogram(linked, labels=labelList)
#                 plt.show()
#     pd.set_option('display.width', 80) # restore default
    return df

# %% [markdown]
# ## Test with Eugene Onegin chapter 1

# %%
explore("data_samples/eo1.xml", 1, True) # no return; explore() writes the output
# Out:
# 0
#     PoemId  StanzaNo  LineNo  \
# 0    Eo.1   1         1
# 1    Eo.1   1         2
# 2    Eo.1   1         3
# 3    Eo.1   1         4
# 4    Eo.1   1         5
# 5    Eo.1   1         6
# 6    Eo.1   1         7
# 7    Eo.1   1         8
# 8    Eo.1   1         9
# 9    Eo.1   1         10
# 10   Eo.1   1         11
# 11   Eo.1   1         12
# 12   Eo.1   1         13
# 13   Eo.1   1         14
# 14   Eo.1   2         1
# 15   Eo.1   2         2
# 16   Eo.1   2         3
# 17   Eo.1   2         4
# 18   Eo.1   2         5
# 19   Eo.1   2         6
# 20   Eo.1   2         7
# 21   Eo.1   2         8
# 22   Eo.1   2         9
# 23   Eo.1   2         10
# 24   Eo.1   2         11
# 25   Eo.1   2         12
# 26   Eo.1   2         13
# 27   Eo.1   2         14
# 28   Eo.1   3         1
# 29   Eo.1   3         2
# ..    ...  ..        ..
# 726  Eo.1   58        13
# 727  Eo.1   58        14
# 728  Eo.1   59        1
# 729  Eo.1   59        2
# 730  Eo.1   59        3
# 731  Eo.1   59        4
# 732  Eo.1   59        5
# 733  Eo.1   59        6
# 734  Eo.1   59        7
# 735  Eo.1   59        8
# 736  Eo.1   59        9
# 737  Eo.1   59        10
# 738  Eo.1   59        11
# 739  Eo.1   59        12
# 740  Eo.1   59        13
# 741  Eo.1   59        14
# 742  Eo.1   60        1
# 743  Eo.1   60        2
# 744  Eo.1   60        3
# 745  Eo.1   60        4
# 746  Eo.1   60        5
# 747  Eo.1   60        6
# 748  Eo.1   60        7
# 749  Eo.1   60        8
# 750  Eo.1   60        9
# 751  Eo.1   60        10
# 752  Eo.1   60        11
# 753  Eo.1   60        12
# 754  Eo.1   60        13
# 755  Eo.1   60        14
#
#                                                                            Text  \
# 0    <line lineNo="001">"Мой дядя самых честных пр<stress>а</stress>вил,</line>
# 1    <line lineNo="002">Когда не в шутку занем<stress>о</stress>г,</line>
# 2    <line lineNo="003">Он уважать себя заст<stress>а</stress>вил</line>
# 3    <line lineNo="004">И лучше выдумать не м<stress>о</stress>г.</line>
# 4    <line lineNo="005">Его пример другим на<stress>у</stress>ка;</line>
# 5    <line lineNo="006">Но, боже мой, какая ск<stress>у</stress>ка</line>
# 6    <line lineNo="007">С больным сидеть и день и н<stress>о</stress>чь,</line>
# 7    <line lineNo="008">Не отходя ни шагу пр<stress>о</stress>чь!</line>
# 8    <line lineNo="009">Какое низкое ков<stress>а</stress>рство</line>
# 9    <line lineNo="010">Полу-живого забавл<stress>я</stress>ть,</line>
# 10   <line lineNo="011">Ему подушки поправл<stress>я</stress>ть,</line>
# 11   <line lineNo="012">Печально подносить лек<stress>а</stress>рство,</line>
# 12   <line lineNo="013">Вздыхать и думать про себ<stress>я</stress>:</line>
# 13   <line lineNo="014">Когда же чорт возьмет теб<stress>я</stress>!"</line>
# 14   <line lineNo="001">Так думал молодой пов<stress>е</stress>са,</line>
# 15   <line lineNo="002">Летя в пыли на почтов<stress>ы</stress>х,</line>
# 16   <line lineNo="003">Всевышней волею Зев<stress>е</stress>са</line>
# 17   <line lineNo="004">Наследник всех своих родн<stress>ы</stress>х.—</line>
# 18   <line lineNo="005">Друзья Людмилы и Русл<stress>а</stress>на!</line>
# 19   <line lineNo="006">С героем моего ром<stress>а</stress>на</line>
# 20   <line lineNo="007">Без предисловий, сей же ч<stress>а</stress>с</line>
# 21   <line lineNo="008">Позвольте познакомить в<stress>а</stress>с:</line>
# 22   <line lineNo="009">Онегин, добрый мой при<stress>я</stress>тель,</line>
# 23   <line lineNo="010">Родился на брегах Нев<stress>ы</stress>,</line>
# 24   <line lineNo="011">Где может быть родились в<stress>ы</stress>,</line>
# 25   <line lineNo="012">Или блистали, мой чит<stress>а</stress>тель;</line>
# 26   <line lineNo="013">Там некогда гулял и <stress>я</stress>:</line>
# 27   <line lineNo="014">Но вреден север для мен<stress>я</stress>.</line>
# 28   <line lineNo="001">Служив отлично-благор<stress>о</stress>дно,</line>
# 29   <line lineNo="002">Долгами жил его от<stress>е</stress>ц,</line>
# ..                                                                ...
# 726  <line lineNo="013">Поймал и славу между т<stress>е</stress>м:</line>
# 727  <line lineNo="014">Но я, любя, был глуп и н<stress>е</stress>м.</line>
# 728  <line lineNo="001">Прошла любовь, явилась М<stress>у</stress>за,</line>
# 729  <line lineNo="002">И прояснился темный <stress>у</stress>м.</line>
# 730  <line lineNo="003">Свободен, вновь ищу со<stress>ю</stress>за</line>
# 731  <line lineNo="004">Волшебных звуков, чувств и д<stress>у</stress>м;</line>
# 732  <line lineNo="005">Пишу, и сердце не тоск<stress>у</stress>ет,</line>
# 733  <line lineNo="006">Перо, забывшись, не рис<stress>у</stress>ет,</line>
# 734  <line lineNo="007">Близ неоконченных стих<stress>о</stress>в,</line>
# 735  <line lineNo="008">Ни женских ножек, ни гол<stress>о</stress>в;</line>
# 736  <line lineNo="009">Погасший пепел уж не всп<stress>ы</stress>хнет,</line>
# 737  <line lineNo="010">Я все грущу: но слез уж н<stress>е</stress>т,</line>
# 738  <line lineNo="011">И скоро, скоро бури сл<stress>е</stress>д</line>
# 739  <line lineNo="012">В душе моей совсем ут<stress>и</stress>хнет:</line>
# 740  <line lineNo="013">Тогда-то я начну пис<stress>а</stress>ть</line>
# 741  <line lineNo="014">Поэму песен в двадцать п<stress>я</stress>ть.</line>
# 742  <line lineNo="001">Я думал уж о форме пл<stress>а</stress>на,</line>
# 743  <line lineNo="002">И как героя назов<stress>у</stress>;</line>
# 744  <line lineNo="003">Покаместь моего ром<stress>а</stress>на</line>
# 745  <line lineNo="004">Я кончил первую глав<stress>у</stress>:</line>
# 746  <line lineNo="005">Пересмотрел все это стр<stress>о</stress>го;</line>
# 747  <line lineNo="006">Противоречний очень мн<stress>о</stress>го,</line>
# 748  <line lineNo="007">Но их исправить не хоч<stress>у</stress>;</line>
# 749  <line lineNo="008">Цензуре долг свой заплач<stress>у</stress>,</line>
# 750  <line lineNo="009">И журналистам на съед<stress>е</stress>нье</line>
# 751  <line lineNo="010">Плоды трудов моих отд<stress>а</stress>м:</line>
# 752  <line lineNo="011">Иди же к невским берег<stress>а</stress>м,</line>
# 753  <line lineNo="012">Новорожденное твор<stress>е</stress>нье,</line>
# 754  <line lineNo="013">И заслужи мне славы д<stress>а</stress>нь:</line>
# 755  <line lineNo="014">Кривые толки, шум и бр<stress>а</stress>нь!</line>
#
#                           Phonetic           RhymeWord RhymeZone  \
# 0    maJ DiDi samix Čistnix prAVil  prAVil              AVil
# 1    kagda Nifšutku zaNimOk         zaNimOk             Ok
# 2    an uvažaT SiBi zastAVil        zastAVil            AVil
# 3    iluČši vidumaT NimOk           NimOk               Ok
# 4    Jiva pRiMir druGim naUka       naUka               Uka
# 5    nabaži maJ kakaJi skUka        skUka               Uka
# 6    zbaLnim SiDiT iDiN inOČ        inOČ                OČ
# 7    NiatxaDi Nišagu prOČ           prOČ                OČ
# 8    kakaJi NiskaJi kavArstva       kavArstva           Arstva
# 9    palu-živava zabavLAT           zabavLAT            AT
# 10   Jimu padušKi papravLAT         papravLAT           AT
# 11   PiČiLna padnaSiT LikArstva     LikArstva           Arstva
# 12   vzdixaT idumaT praSiBA         praSiBA             BA
# 13   kagdaži Čirt vaZMit TiBA       TiBA                BA
# 14   tak dumal maladaJ paVEsa       paVEsa              Esa
# 15   LiTi fpiLi napaČtavIx          napaČtavIx          Ix
# 16   fSivišNiJ vaLiJu ZiVEsa        ZiVEsa              Esa
# 17   naSLiDNik fSix svaJix radnIx   radnIx              Ix
# 18   druZJi LudMili iruslAna        iruslAna            Ana
# 19   zGiraJim maJiva ramAna         ramAna              Ana
# 20   BispRiDislaViJ SiJži ČAs       ČAs                 As
# 21   pazvaLTi paznakaMiT vAs        vAs                 As
# 22   aNiGin dabriJ maJ pRiJATiL     pRiJATiL            ATiL
# 23   raDilSi nabRigax NivI          NivI                vI
# 24   gDi mažit biT raDiLiS vI       vI                  vI
# 25   iLibListaLi maJ ČitATiL        ČitATiL             ATiL
# 26   tam Nikagda guLil iJA          iJA                 JA
# 27   navRiDin SiVir DLiMiNA         DLiMiNA             NA
# 28   služif aTLiČna-blagarOdna      aTLiČna-blagarOdna  Odna
# 29   dalgaMi žil Jiva aTEts         aTEts               Ets
# ..                      ...           ...               ...
# 726  paJmal islavu Miždu TEm        TEm                 Em
# 727  naJi LuBi bil glup iNEm        iNEm                Em
# 728  prašla LubaF JiVilaS mUza      mUza                Uza
# 729  ipraJiSNilSi TimniJ Um         Um                  Um
# 730  svabaDin vnaF iQu saJUza       saJUza              Uza
# 731  valšibnix zvukaf Čufstf idUm   idUm                Um
# 732  Pišu iSirtsi NitaskUJit        NitaskUJit          UJit
# 733  Pira zabifšiS NiRisUJit        NiRisUJit           UJit
# 734  bLiZNiakaNČinix STixOf         STixOf              Of
# 735  NižinsKix nažik NigalOf        NigalOf             Of
# 736  pagasšiJ PiPil uš NifspIxNit   NifspIxNit          IxNit
# 737  Ji fSi gruQu naSLis uš NEt     NEt                 Et
# 738  iskara skara buRi SLEt         SLEt                Et
# 739  vduši maJiJ safSim uTIxNit     uTIxNit             IxNit
# 740  tagda-taJi naČnu PisAT         PisAT               AT
# 741  paimu PiSin vdvatsaT PAT       PAT                 AT
# 742  Ji dumal uš afarMi plAna       plAna               Ana
# 743  ikak GiraJi nazavU             nazavU              vU
# 744  pakaMiST maJiva ramAna         ramAna              Ana
# 745  Ji kaNČil PirvuJu glavU        glavU               vU
# 746  PiRismatRil fSi ita strOga     strOga              Oga
# 747  praTivaRiČNiJ aČiN mnOga       mnOga               Oga
# 748  naJix ispraViT NixaČU          NixaČU              ČU
# 749  tsinzuRi dalk svaJ zaplaČU     zaplaČU             ČU
# 750  ižurnaListam naSJiDENJi        naSJiDENJi          ENJi
# 751  pladi trudaf maJix adAm        adAm                Am
# 752  iDiži kNifsKim BiRigAm         BiRigAm             Am
# 753  navaražDinaJi tvaRENJi         tvaRENJi            ENJi
# 754  izasluži mNi slavi dAN         dAN                 AN
# 755  kRiviJi talKi šum ibrAN        ibrAN               AN
#
#                                       tokenized   token0 token1   token2  \
# 0    (, A, V, i, l, , , , , , , , , , , , , )    missing  A      V
# 1    (, O, k, , , , , , , , , , , , , , , )      missing  O      k
# 2    (, A, V, i, l, , , , , , , , , , , , , )    missing  A      V
# 3    (, O, k, , , , , , , , , , , , , , , )      missing  O      k
# 4    (, U, k, a, , , , , , , , , , , , , , )     missing  U      k
# 5    (, U, k, a, , , , , , , , , , , , , , )     missing  U      k
# 6    (, O, Č, , , , , , , , , , , , , , , )      missing  O      Č
# 7    (, O, Č, , , , , , , , , , , , , , , )      missing  O      Č
# 8    (, A, rstv, a, , , , , , , , , , , , , , )  missing  A      rstv
# 9    (, A, T, , , , , , , , , , , , , , , )      missing  A      T
# 10   (, A, T, , , , , , , , , , , , , , , )      missing  A      T
# 11   (, A, rstv, a, , , , , , , , , , , , , , )  missing  A      rstv
# 12   (B, A, , , , , , , , , , , , , , , , )      B        A      missing
# 13   (B, A, , , , , , , , , , , , , , , , )      B        A      missing
# 14   (, E, s, a, , , , , , , , , , , , , , )     missing  E      s
# 15   (, I, x, , , , , , , , , , , , , , , )      missing  I      x
# 16   (, E, s, a, , , , , , , , , , , , , , )     missing  E      s
# 17   (, I, x, , , , , , , , , , , , , , , )      missing  I      x
# 18   (, A, n, a, , , , , , , , , , , , , , )     missing  A      n
# 19   (, A, n, a, , , , , , , , , , , , , , )     missing  A      n
# 20   (, A, s, , , , , , , , , , , , , , , )      missing  A      s
# 21   (, A, s, , , , , , , , , , , , , , , )      missing  A      s
# 22   (, A, T, i, L, , , , , , , , , , , , , )    missing  A      T
# 23   (v, I, , , , , , , , , , , , , , , , )      v        I      missing
# 24   (v, I, , , , , , , , , , , , , , , , )      v        I      missing
# 25   (, A, T, i, L, , , , , , , , , , , , , )    missing  A      T
# 26   (J, A, , , , , , , , , , , , , , , , )      J        A      missing
# 27   (N, A, , , , , , , , , , , , , , , , )      N        A      missing
# 28   (, O, dn, a, , , , , , , , , , , , , , )    missing  O      dn
# 29   (, E, ts, , , , , , , , , , , , , , , )     missing  E      ts
# ..                                       ...         ... ..      ..
# 726  (, E, m, , , , , , , , , , , , , , , )      missing  E      m
# 727  (, E, m, , , , , , , , , , , , , , , )      missing  E      m
# 728  (, U, z, a, , , , , , , , , , , , , , )     missing  U      z
# 729  (, U, m, , , , , , , , , , , , , , , )      missing  U      m
# 730  (, U, z, a, , , , , , , , , , , , , , )     missing  U      z
# 731  (, U, m, , , , , , , , , , , , , , , )      missing  U      m
# 732  (, U, J, i, t, , , , , , , , , , , , , )    missing  U      J
# 733  (, U, J, i, t, , , , , , , , , , , , , )    missing  U      J
# 734  (, O, f, , , , , , , , , , , , , , , )      missing  O      f
# 735  (, O, f, , , , , , , , , , , , , , , )      missing  O      f
# 736  (, I, xN, i, t, , , , , , , , , , , , , )   missing  I      xN
# 737  (, E, t, , , , , , , , , , , , , , , )      missing  E      t
# 738  (, E, t, , , , , , , , , , , , , , , )      missing  E      t
# 739  (, I, xN, i, t, , , , , , , , , , , , , )   missing  I      xN
# 740  (, A, T, , , , , , , , , , , , , , , )      missing  A      T
# 741  (, A, T, , , , , , , , , , , , , , , )      missing  A      T
# 742  (, A, n, a, , , , , , , , , , , , , , )     missing  A      n
# 743  (v, U, , , , , , , , , , , , , , , , )      v        U      missing
# 744  (, A, n, a, , , , , , , , , , , , , , )     missing  A      n
# 745  (v, U, , , , , , , , , , , , , , , , )      v        U      missing
# 746  (, O, g, a, , , , , , , , , , , , , , )     missing  O      g
# 747  (, O, g, a, , , , , , , , , , , , , , )     missing  O      g
# 748  (Č, U, , , , , , , , , , , , , , , , )      Č        U      missing
# 749  (Č, U, , , , , , , , , , , , , , , , )      Č        U      missing
# 750  (, E, NJ, i, , , , , , , , , , , , , , )    missing  E      NJ
# 751  (, A, m, , , , , , , , , , , , , , , )      missing  A      m
# 752  (, A, m, , , , , , , , , , , , , , , )      missing  A      m
# 753  (, E, NJ, i, , , , , , , , , , , , , , )    missing  E      NJ
# 754  (, A, N, , , , , , , , , , , , , , , )      missing  A      N
# 755  (, A, N, , , , , , , , , , , , , , , )      missing  A      N
#
#       token3   token4 token0_Syllabic token0_High token0_Delayedrelease  \
# 0    i        l        hi              hi          hi
# 1    missing  missing  hi              hi          hi
# 2    i        l        hi              hi          hi
# 3    missing  missing  hi              hi          hi
# 4    a        missing  hi              hi          hi
# 5    a        missing  hi              hi          hi
# 6    missing  missing  hi              hi          hi
# 7    missing  missing  hi              hi          hi
# 8    a        missing  hi              hi          hi
# 9    missing  missing  hi              hi          hi
# 10   missing  missing  hi              hi          hi
# 11   a        missing  hi              hi          hi
# 12   missing  missing  hi              hi          hi
# 13   missing  missing  hi              hi          hi
# 14   a        missing  hi              hi          hi
# 15   missing  missing  hi              hi          hi
# 16   a        missing  hi              hi          hi
# 17   missing  missing  hi              hi          hi
# 18   a        missing  hi              hi          hi
# 19   a        missing  hi              hi          hi
# 20   missing  missing  hi              hi          hi
# 21   missing  missing  hi              hi          hi
# 22   i        L        hi              hi          hi
# 23   missing  missing  hi              hi          hi
# 24   missing  missing  hi              hi          hi
# 25   i        L        hi              hi          hi
# 26   missing  missing  hi              hi          hi
# 27   missing  missing  hi              hi          hi
# 28   a        missing  hi              hi          hi
# 29   missing  missing  hi              hi          hi
# ..       ...      ...  ..              ..          ..
# 726  missing  missing  hi              hi          hi
# 727  missing  missing  hi              hi          hi
# 728  a        missing  hi              hi          hi
# 729  missing  missing  hi              hi          hi
# 730  a        missing  hi              hi          hi
# 731  missing  missing  hi              hi          hi
# 732  i        t        hi              hi          hi
# 733  i        t        hi              hi          hi
# 734  missing  missing  hi              hi          hi
# 735  missing  missing  hi              hi          hi
# 736  i        t        hi              hi          hi
# 737  missing  missing  hi              hi          hi
# 738  missing  missing  hi              hi          hi
# 739  i        t        hi              hi          hi
# 740  missing  missing  hi              hi          hi
# 741  missing  missing  hi              hi          hi
# 742  a        missing  hi              hi          hi
# 743  missing  missing  hi              hi          hi
# 744  a        missing  hi              hi          hi
# 745  missing  missing  hi              hi          hi
# 746  a        missing  hi              hi          hi
# 747  a        missing  hi              hi          hi
# 748  missing  missing  hi              hi          hi
# 749  missing  missing  hi              hi          hi
# 750  i        missing  hi              hi          hi
# 751  missing  missing  hi              hi          hi
# 752  missing  missing  hi              hi          hi
# 753  i        missing  hi              hi          hi
# 754  missing  missing  hi              hi          hi
# 755  missing  missing  hi              hi          hi
#
#     token0_Palatalized token0_Lateral token0_Anterior token0_Low token0_Back  \
# 0    hi                 hi             hi              hi         hi
# 1    hi                 hi             hi              hi         hi
# 2    hi                 hi             hi              hi         hi
