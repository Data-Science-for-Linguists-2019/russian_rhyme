# %% [markdown]
# ## Progress report 2 notebook

# %% [markdown]
# This notebook loads and parses a sample of the XML data used in the project. A general report that includes more information about the project is available in the [project report](progress_report.md).
#
# This notebook continues [progress_report_1.ipynb](progress_report_1.ipynb), integrating improvements, corrections, and new functionality. This is the *existing* option for report 2, renamed for easy access to and comparison of the two stages.

# %% [markdown]
# ## Sample data
#
# The sample dataset consists of multiple stanzas from a long poem. An artificial one-stanza extract looks like the following:

# %% [markdown]
# ```xml
# <poem>
#     <stanza stanzaNo="001">
#         <line lineNo="001">"Мой дядя самых честных пр<stress>а</stress>вил,</line>
#         <line lineNo="002">Когда не в шутку занем<stress>о</stress>г,</line>
#         <line lineNo="003">Он уважать себя заст<stress>а</stress>вил</line>
#         <line lineNo="004">И лучше выдумать не м<stress>о</stress>г.</line>
#         <line lineNo="005">Его пример другим на<stress>у</stress>ка;</line>
#         <line lineNo="006">Но, боже мой, какая ск<stress>у</stress>ка</line>
#         <line lineNo="007">С больным сидеть и день и н<stress>о</stress>чь,</line>
#         <line lineNo="008">Не отходя ни шагу пр<stress>о</stress>чь!</line>
#         <line lineNo="009">Какое низкое ков<stress>а</stress>рство</line>
#         <line lineNo="010">Полу-живого забавл<stress>я</stress>ть,</line>
#         <line lineNo="011">Ему подушки поправл<stress>я</stress>ть,</line>
#         <line lineNo="012">Печально подносить лек<stress>а</stress>рство,</line>
#         <line lineNo="013">Вздыхать и думать про себ<stress>я</stress>:</line>
#         <line lineNo="014">Когда же чорт возьмет теб<stress>я</stress>!"</line>
#     </stanza>
# </poem>
# ```

# %% [markdown]
# ## Reload libraries each time, since we’re tinkering with them

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load libraries

# %%
from xml.dom import pulldom  # parse input XML
from xml.dom.minidom import Document  # construct output XML
import numpy as np
import pandas as pd
import regex as re
from cyr2phon import cyr2phon, utility  # custom package

# %% [markdown]
# ## Class and variables for parsing input XML

# %%
class Stack(list):  # keep track of open nodes while constructing XML output
    def push(self, item):
        self.append(item)

    def peek(self):  
        return self[-1]


open_elements = Stack()
WS_RE = re.compile(r'\s+')  # normalize white space in output

# %% [markdown]
# ## Function to parse the XML
#
# Returns a list of lists, with stanza number, line number, and `<line>` element for each line. We use the light-weight *xml.dom.pulldom* library to parse the input XML and *xml.dom.minidom* to construct the lines as simplified XML, removing elements we don’t care about, such as `<latin>` and `<italic>`, before serializing them to the output. (We actually do care about `<latin>`, but we are ignoring it temporarily, and we’ll return to it at a later stage in the project.)

# %%
def process(input_xml):
    stanzaNo = 0
    lineNo = 0
    inline = 0  # flag to control behavior inside and outside lines
    result = []  # array of arrays, one per line, with stanzaNo, lineNo, and serialized XML
    doc = pulldom.parse(input_xml)
    for event, node in doc:
        if event == pulldom.START_ELEMENT and node.localName == 'stanza':
            stanzaNo = node.getAttribute("stanzaNo")
        elif event == pulldom.START_ELEMENT and node.localName == 'line':
            d = Document()  # each line is an output XML document
            open_elements.push(d)  # document node
            lineNo = node.getAttribute("lineNo")
            inline = 1  # we’re inside a line
            open_elements.peek().appendChild(node)  # add as child of current node in output tree
            open_elements.push(node)  # keep track of open elements
        elif event == pulldom.END_ELEMENT and node.localName == 'line':
            inline = 0  # when we finish our work here, we’ll no longer be inside a line
            open_elements.pop()  # line is finished
            # serialize XML, strip declaration, rewrite &quot; entity as character
            result.append([int(stanzaNo), int(lineNo),
                WS_RE.sub(" " ,
                open_elements.pop().toxml().replace('<?xml version="1.0" ?>', '').replace('&quot;', '"'))])
        elif event == pulldom.START_ELEMENT and node.localName == 'stress':
            open_elements.peek().appendChild(node)  # add as child of current node in output tree
            open_elements.push(node)  # keep track of open elements
        elif event == pulldom.END_ELEMENT and node.localName == 'stress':
            open_elements.pop()  # stress element is finished
        elif event == pulldom.CHARACTERS and inline:  # keep text only inside lines
            t = d.createTextNode(node.data)
            open_elements.peek().appendChild(t)
    return result

# %% [markdown]
# ## Parse the XML into an array of arrays

# %%
with open("data_samples/eo1.xml") as f:
    all_lines = process(f)
all_lines[:5]  # take a look
# Out:
# [[1,
#   1,
#   '<line lineNo="001">"Мой дядя самых честных пр<stress>а</stress>вил,</line>'],
#  [1,
#   2,
#   '<line lineNo="002">Когда не в шутку занем<stress>о</stress>г,</line>'],
#  [1, 3, '<line lineNo="003">Он уважать себя заст<stress>а</stress>вил</line>'],
#  [1, 4, '<line lineNo="004">И лучше выдумать не м<stress>о</stress>г.</line>'],
#  [1, 5, '<line lineNo="005">Его пример другим на<stress>у</stress>ка;</line>']]

# %% [markdown]
# ## General descriptive information
#
# Use `//` for integer division to return *54* instead of *54.0*.

# %%
line_count = len(all_lines)
print ('There are ' + str(line_count // 14) + ' 14-line stanzas in this sample, with a total of ' + 
       str(line_count) + ' lines. Since we know that the poem is fully rhymed, there are ' + 
       str(line_count // 2) + ' rhyme pairs in the sample.')
# Out:
# There are 54 14-line stanzas in this sample, with a total of 756 lines. Since we know that the poem is fully rhymed, there are 378 rhyme pairs in the sample.

# %% [markdown]
# ## Write the data into a dataframe

# %%
df = pd.DataFrame(all_lines, columns=["StanzaNo", "LineNo", "Text"])
df.head(5)
# Out:
#    StanzaNo  LineNo                                               Text
# 0         1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1         1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 2         1       3  <line lineNo="003">Он уважать себя заст<stress...
# 3         1       4  <line lineNo="004">И лучше выдумать не м<stres...
# 4         1       5  <line lineNo="005">Его пример другим на<stress...

# %% [markdown]
# ## Transliterate all lines and save in new column
#
# ### Notes
#
# 1. Because only the last stress in the line is marked, the phonetic representation of all words except the last is incorrect. That doesn’t matter for the analysis of end rhyme.
# 1. Words in foreign languages are not being treated specially, and are therefore usually phonetically incorrect. That *does* matter for the analysis of end rhyme. Deal with it later, first by excluding those lines (revise the XML parsing to record that information), and eventually by phoneticizing them correctly.
# 1. The `transliterate()` function is part of the [custom *cyr2phon* package](cyr2phon/cyr2phon.py).

# %%
trans_vec = np.vectorize(cyr2phon.transliterate)
df["Phonetic"] = trans_vec(df["Text"])
df.head()  # take a look
# Out:
#    StanzaNo  LineNo                                               Text  \
# 0         1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1         1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 2         1       3  <line lineNo="003">Он уважать себя заст<stress...
# 3         1       4  <line lineNo="004">И лучше выдумать не м<stres...
# 4         1       5  <line lineNo="005">Его пример другим на<stress...
#
#                         Phonetic
# 0  maJ DiDi samix Čistnix prAVil
# 1         kagda Nifšutku zaNimOk
# 2        an uvažaT SiBi zastAVil
# 3           iluČši vidumaT NimOk
# 4       Jiva pRiMir druGim naUka

# %% [markdown]
# ## Write the rhyme word into a new column

# %%
df["RhymeWord"] = df["Phonetic"].str.split().str[-1]
df.head()  # take a look
# Out:
#    StanzaNo  LineNo                                               Text  \
# 0         1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1         1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 2         1       3  <line lineNo="003">Он уважать себя заст<stress...
# 3         1       4  <line lineNo="004">И лучше выдумать не м<stres...
# 4         1       5  <line lineNo="005">Его пример другим на<stress...
#
#                         Phonetic RhymeWord
# 0  maJ DiDi samix Čistnix prAVil    prAVil
# 1         kagda Nifšutku zaNimOk   zaNimOk
# 2        an uvažaT SiBi zastAVil  zastAVil
# 3           iluČši vidumaT NimOk     NimOk
# 4       Jiva pRiMir druGim naUka     naUka

# %% [markdown]
# ## Syllabify rhyme word and write into new column
#
# The `syllabify()` function is part of the [custom *utility* package](cyr2phon/utility.py).

# %%
df["Syllabified"] = [utility.syllabify(word) for word in df["RhymeWord"]]
df.head()
# writing a list into a cell isn’t good practice; is it okay as a stepping stone?
# Out:
#    StanzaNo  LineNo                                               Text  \
# 0         1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1         1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 2         1       3  <line lineNo="003">Он уважать себя заст<stress...
# 3         1       4  <line lineNo="004">И лучше выдумать не м<stres...
# 4         1       5  <line lineNo="005">Его пример другим на<stress...
#
#                         Phonetic RhymeWord     Syllabified
# 0  maJ DiDi samix Čistnix prAVil    prAVil      [prA, Vil]
# 1         kagda Nifšutku zaNimOk   zaNimOk   [za, Ni, mOk]
# 2        an uvažaT SiBi zastAVil  zastAVil  [za, stA, Vil]
# 3           iluČši vidumaT NimOk     NimOk       [Ni, mOk]
# 4       Jiva pRiMir druGim naUka     naUka     [na, U, ka]

# %% [markdown]
# ## Identify rhyme zone and write into new column
#
# The *rhyme zone* is the portion of the line that participates in line end-rhyme. According to Russian rhyming conventions, the rhyme zone typically begins with the last stressed vowel of the line and continues until the end of the line. The one exception is that in Russian open masculine rhyme (that is, rhyme involving stress on a final syllable that ends in a vowel) also requires a *supporting consonant*, that is, it also requires that the consonants *before the stressed vowels* (not otherwise considered part of the rhyme zone* also agree. For example:
#
# * _see_ and _tree_ do not rhyme in Russian because this open (ends in a vowel sound) masculine (stress on the final syllable) rhyme does not have a supporting consonant (consonants before the stressed vowels do not agree).
# * *seat* and *treat* do rhyme in Russian because closed (ends in a consonant sound) masculine (stress on the final syllable) rhyme does not require a supporting consonant, so the lack of phonetic correspondence between the consonants before the stressed vowels does not matter.
#
# Russian rhyme may also be *enriched* by phonetic agreement or similarity outside the rhyme zone. For example, *stop* and *strop* constitute a perfect rhyme because the *op* sounds match. Nonetheless, the match of *st* before the rhyme zone enhances, or enriches, the rhyme. The present study ignores enrichment and concentrates only on the core rhyme components, but enrichment will be incorporated into the analysis at a later stage.
#
# With that said, this first pass at identifying the rhyme zone removes the pretonic syllables, but not the pretonic onset where a supporting consonant is not needed. More cleaning to follow!

# %%
def remove_pretonic_syllables(l: list) -> list: # removes syllables in place
    for position, syllable in enumerate(l):
        if re.search(r'[AEIOU]', syllable): # rhyme zone begins here
            l = l[position:]
            return l
df["RhymeZone"] = df["Syllabified"].apply(remove_pretonic_syllables)
df.head(10)
# Out:
#    StanzaNo  LineNo                                               Text  \
# 0         1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1         1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 2         1       3  <line lineNo="003">Он уважать себя заст<stress...
# 3         1       4  <line lineNo="004">И лучше выдумать не м<stres...
# 4         1       5  <line lineNo="005">Его пример другим на<stress...
# 5         1       6  <line lineNo="006">Но, боже мой, какая ск<stre...
# 6         1       7  <line lineNo="007">С больным сидеть и день и н...
# 7         1       8  <line lineNo="008">Не отходя ни шагу пр<stress...
# 8         1       9  <line lineNo="009">Какое низкое ков<stress>а</...
# 9         1      10  <line lineNo="010">Полу-живого забавл<stress>я...
#
#                         Phonetic  RhymeWord      Syllabified    RhymeZone
# 0  maJ DiDi samix Čistnix prAVil     prAVil       [prA, Vil]   [prA, Vil]
# 1         kagda Nifšutku zaNimOk    zaNimOk    [za, Ni, mOk]        [mOk]
# 2        an uvažaT SiBi zastAVil   zastAVil   [za, stA, Vil]   [stA, Vil]
# 3           iluČši vidumaT NimOk      NimOk        [Ni, mOk]        [mOk]
# 4       Jiva pRiMir druGim naUka      naUka      [na, U, ka]      [U, ka]
# 5        nabaži maJ kakaJi skUka      skUka        [skU, ka]    [skU, ka]
# 6        zbaLnim SiDiT iDiN inOČ       inOČ         [i, nOČ]        [nOČ]
# 7           NiatxaDi Nišagu prOČ       prOČ           [prOČ]       [prOČ]
# 8       kakaJi NiskaJi kavArstva  kavArstva  [ka, vAr, stva]  [vAr, stva]
# 9           palu-živava zabavLAT   zabavLAT   [za, ba, vLAT]       [vLAT]

# %% [markdown]
# Note to self: Mutable objects inside a DataFrame require extra care.

# %% [markdown]
# ## Remove pretonic onsets from syllables that do not require supporting consonant
#
# We may want to treat this differently down the road, perhaps retaining pretonic onsets and letting the data tell us that they have to match only with open masculine rhymes. For now, though, we’ll following the handbook definition of canonic Russian rhyme.

# %%
df["StrippedRhymeZone"] = df["RhymeZone"].apply(utility.strip_onset)
df.head()
# Out:
#    StanzaNo  LineNo                                               Text  \
# 0         1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1         1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 2         1       3  <line lineNo="003">Он уважать себя заст<stress...
# 3         1       4  <line lineNo="004">И лучше выдумать не м<stres...
# 4         1       5  <line lineNo="005">Его пример другим на<stress...
#
#                         Phonetic RhymeWord     Syllabified   RhymeZone  \
# 0  maJ DiDi samix Čistnix prAVil    prAVil      [prA, Vil]  [prA, Vil]
# 1         kagda Nifšutku zaNimOk   zaNimOk   [za, Ni, mOk]       [mOk]
# 2        an uvažaT SiBi zastAVil  zastAVil  [za, stA, Vil]  [stA, Vil]
# 3           iluČši vidumaT NimOk     NimOk       [Ni, mOk]       [mOk]
# 4       Jiva pRiMir druGim naUka     naUka     [na, U, ka]     [U, ka]
#
#   StrippedRhymeZone
# 0          [A, Vil]
# 1              [Ok]
# 2          [A, Vil]
# 3              [Ok]
# 4           [U, ka]

# %%
df.loc[[0, 1, 12]] # 0 = feminine, 1 = closed masculine, 12 = open masculine
# Out:
#     StanzaNo  LineNo                                               Text  \
# 0          1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1          1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 12         1      13  <line lineNo="013">Вздыхать и думать про себ<s...
#
#                          Phonetic RhymeWord    Syllabified   RhymeZone  \
# 0   maJ DiDi samix Čistnix prAVil    prAVil     [prA, Vil]  [prA, Vil]
# 1          kagda Nifšutku zaNimOk   zaNimOk  [za, Ni, mOk]       [mOk]
# 12         vzdixaT idumaT praSiBA   praSiBA  [pra, Si, BA]        [BA]
#
#    StrippedRhymeZone
# 0           [A, Vil]
# 1               [Ok]
# 12              [BA]

# %% [markdown]
# ## Write each syllable into a separate column

# %%
df["syllcounts"] = df["StrippedRhymeZone"].apply(len) 
maxSylls = df["syllcounts"].max() # longest word in syllable count; hold on to this for processing later
for i in range(maxSylls): # Use max syllable count in StrippedRhymeZone to create tonic, posttonic, etc. columns
    df['t' + str(i)] = [x[i] if len(x) > i else None for x in df["StrippedRhymeZone"] ]
df.head()
# Out:
#    StanzaNo  LineNo                                               Text  \
# 0         1       1  <line lineNo="001">"Мой дядя самых честных пр<...
# 1         1       2  <line lineNo="002">Когда не в шутку занем<stre...
# 2         1       3  <line lineNo="003">Он уважать себя заст<stress...
# 3         1       4  <line lineNo="004">И лучше выдумать не м<stres...
# 4         1       5  <line lineNo="005">Его пример другим на<stress...
#
#                         Phonetic RhymeWord     Syllabified   RhymeZone  \
# 0  maJ DiDi samix Čistnix prAVil    prAVil      [prA, Vil]  [prA, Vil]
# 1         kagda Nifšutku zaNimOk   zaNimOk   [za, Ni, mOk]       [mOk]
# 2        an uvažaT SiBi zastAVil  zastAVil  [za, stA, Vil]  [stA, Vil]
# 3           iluČši vidumaT NimOk     NimOk       [Ni, mOk]       [mOk]
# 4       Jiva pRiMir druGim naUka     naUka     [na, U, ka]     [U, ka]
#
#   StrippedRhymeZone  syllcounts  t0    t1
# 0          [A, Vil]           2   A   Vil
# 1              [Ok]           1  Ok  None
# 2          [A, Vil]           2   A   Vil
# 3              [Ok]           1  Ok  None
# 4           [U, ka]           2   U    ka

# %% [markdown]
# ## Decompose syllables into segments and write into separate columns

# %%
# for i in range(maxSylls):
#     print(df['t' + str(i)])
pd.set_option('display.max_colwidth', -1)
g = df.groupby(['t0', 't1']).groups
for key, value in g.items():
    print(key, df.loc[value].Text)
# Out:
# ('A', 'Vil') 0    <line lineNo="001">"Мой дядя самых честных пр<stress>а</stress>вил,</line>
# 2    <line lineNo="003">Он уважать себя заст<stress>а</stress>вил</line>
# Name: Text, dtype: object
# ('Ok', nan) 1      <line lineNo="002">Когда не в шутку занем<stress>о</stress>г,</line>
# 3      <line lineNo="004">И лучше выдумать не м<stress>о</stress>г.</line>
# 96     <line lineNo="013">Отец понять его не м<stress>о</stress>г</line>
# 97     <line lineNo="014">И земли отдавал в зал<stress>о</stress>г.</line>
# 174    <line lineNo="007">Вошел: и пробка в потол<stress>о</stress>к,</line>
# 175    <line lineNo="008">Вина кометы брызнул т<stress>о</stress>к,</line>
# 317    <line lineNo="010">Что уж и так мой бедный сл<stress>о</stress>г</line>
# 318    <line lineNo="011">Пестреть гораздо б меньше м<stress>о</stress>г</line>
# 373    <line lineNo="010">Три пары стройных женских н<stress>о</stress>г.</line>
# 374    <line lineNo="011">Ах! долго я забыть не м<stress>о</stress>г</line>
# 468    <line lineNo="007">Затем, что не всегда же м<stress>о</stress>г</line>
# 469    <line lineNo="008"> Beef-steaks и стразбургский пир<stress>о</stress>г</line>
# Name: Text, dtype: object
# ('U', 'ka') 4    <line lineNo="005">Его пример другим на<stress>у</stress>ка;</line>
# 5    <line lineNo="006">Но, боже мой, какая ск<stress>у</stress>ка</line>
# Name: Text, dtype: object
# ('OČ', nan) 6    <line lineNo="007">С больным сидеть и день и н<stress>о</stress>чь,</line>
# 7    <line lineNo="008">Не отходя ни шагу пр<stress>о</stress>чь!</line>
# Name: Text, dtype: object
# ('Ar', 'stva') 8     <line lineNo="009">Какое низкое ков<stress>а</stress>рство</line>
# 11    <line lineNo="012">Печально подносить лек<stress>а</stress>рство,</line>
# Name: Text, dtype: object
# ('AT', nan) 9      <line lineNo="010">Полу-живого забавл<stress>я</stress>ть,</line>
# 10     <line lineNo="011">Ему подушки поправл<stress>я</stress>ть,</line>
# 71     <line lineNo="002">Так, если правду вам сказ<stress>а</stress>ть,</line>
# 73     <line lineNo="004">Чтоб эпиграфы разбир<stress>а</stress>ть,</line>
# 113    <line lineNo="002">Таить надежду, ревнов<stress>а</stress>ть,</line>
# 115    <line lineNo="004">Казаться мрачным, изныв<stress>а</stress>ть,</line>
# 127    <line lineNo="002">Шутя невинность изумл<stress>я</stress>ть,</line>
# 129    <line lineNo="004">Приятной лестью забавл<stress>я</stress>ть,</line>
# 132    <line lineNo="007">Умом и страстью побежд<stress>а</stress>ть,</line>
# 133    <line lineNo="008">Невольной ласки ожид<stress>а</stress>ть,</line>
# 222    <line lineNo="013">Безмолвно буду я зев<stress>а</stress>ть</line>
# 223    <line lineNo="014">И о былом воспомин<stress>а</stress>ть?</line>
# 740    <line lineNo="013">Тогда-то я начну пис<stress>а</stress>ть</line>
# 741    <line lineNo="014">Поэму песен в двадцать п<stress>я</stress>ть.</line>
# Name: Text, dtype: object
# ('BA', nan) 12     <line lineNo="013">Вздыхать и думать про себ<stress>я</stress>:</line>
# 13     <line lineNo="014">Когда же чорт возьмет теб<stress>я</stress>!"</line>
# 121    <line lineNo="010">Одним дыша, одно люб<stress>я</stress>,</line>
# 122    <line lineNo="011">Как он умел забыть себ<stress>я</stress>!</line>
# Name: Text, dtype: object
# ('E', 'sa') 14    <line lineNo="001">Так думал молодой пов<stress>е</stress>са,</line>
# 16    <line lineNo="003">Всевышней волею Зев<stress>е</stress>са</line>
# Name: Text, dtype: object
# ('Ix', nan) 15     <line lineNo="002">Летя в пыли на почтов<stress>ы</stress>х,</line>
# 17     <line lineNo="004">Наследник всех своих родн<stress>ы</stress>х.—</line>
# 141    <line lineNo="002">Сердца кокеток записн<stress>ы</stress>х!</line>
# 143    <line lineNo="004">Ему соперников сво<stress>и</stress>х,</line>
# 432    <line lineNo="013">Слова и взор волшебниц с<stress>и</stress>х</line>
# 433    <line lineNo="014">Обманчивы... как ножки <stress>и</stress>х.</line>
# Name: Text, dtype: object
# ('A', 'na') 18     <line lineNo="005">Друзья Людмилы и Русл<stress>а</stress>на!</line>
# 19     <line lineNo="006">С героем моего ром<stress>а</stress>на</line>
# 742    <line lineNo="001">Я думал уж о форме пл<stress>а</stress>на,</line>
# 744    <line lineNo="003">Покаместь моего ром<stress>а</stress>на</line>
# Name: Text, dtype: object
# ('As', nan) 20     <line lineNo="007">Без предисловий, сей же ч<stress>а</stress>с</line>
# 21     <line lineNo="008">Позвольте познакомить в<stress>а</stress>с:</line>
# 211    <line lineNo="002">Внемлите мой печальный гл<stress>а</stress>с:</line>
# 213    <line lineNo="004">Сменив, не заменили в<stress>а</stress>с?</line>
# 446    <line lineNo="013">В бумажном колпаке, нер<stress>а</stress>з</line>
# 447    <line lineNo="014">Уж отворял свой васисд<stress>а</stress>с. </line>
# 541    <line lineNo="010">Томила жизнь обоих н<stress>а</stress>с;</line>
# 542    <line lineNo="011">В обоих сердца жар уг<stress>а</stress>с;</line>
# 589    <line lineNo="002">О Брента! нет, увижу в<stress>а</stress>с,</line>
# 591    <line lineNo="004">Услышу ваш волшебный гл<stress>а</stress>с!</line>
# Name: Text, dtype: object
# ('A', 'TiL') 22     <line lineNo="009">Онегин, добрый мой при<stress>я</stress>тель,</line>
# 25     <line lineNo="012">Или блистали, мой чит<stress>а</stress>тель;</line>
# 186    <line lineNo="005">Театра злой законод<stress>а</stress>тель,</line>
# 187    <line lineNo="006">Непостоянный обож<stress>а</stress>тель</line>
# 690    <line lineNo="005">Чтобы насмешливый чит<stress>а</stress>тель</line>
# 691    <line lineNo="006">Или какой-нибудь изд<stress>а</stress>тель</line>
# Name: Text, dtype: object
# ('vI', nan) 23    <line lineNo="010">Родился на брегах Нев<stress>ы</stress>,</line>
# 24    <line lineNo="011">Где может быть родились в<stress>ы</stress>,</line>
# Name: Text, dtype: object
# ('JA', nan) 26     <line lineNo="013">Там некогда гулял и <stress>я</stress>:</line>
# 703    <line lineNo="004">Мне снились, и душа мо<stress>я</stress> </line>
# 710    <line lineNo="011">Вопрос нередко слышу <stress>я</stress>:</line>
# Name: Text, dtype: object
# ('NA', nan) 27     <line lineNo="014">Но вреден север для мен<stress>я</stress>.</line>
# 395    <line lineNo="004">Прелестней чем-то для мен<stress>я</stress>.</line>
# Name: Text, dtype: object
# ('O', 'dna') 28    <line lineNo="001">Служив отлично-благор<stress>о</stress>дно,</line>
# 30    <line lineNo="003">Давал три бала ежег<stress>о</stress>дно</line>
# Name: Text, dtype: object
# ('Ets', nan) 29     <line lineNo="002">Долгами жил его от<stress>е</stress>ц,</line>
# 31     <line lineNo="004">И промотался након<stress>е</stress>ц.</line>
# 474    <line lineNo="013">Но разлюбил он након<stress>е</stress>ц</line>
# 475    <line lineNo="014">И брань и саблю и свин<stress>е</stress>ц.</line>
# Name: Text, dtype: object
# ('I', 'la') 32     <line lineNo="005">Судьба Евгения хран<stress>и</stress>ла:</line>
# 33     <line lineNo="006">Сперва Madame за ним ход<stress>и</stress>ла,</line>
# 704    <line lineNo="005">Их образ тайный сохран<stress>и</stress>ла;</line>
# 705    <line lineNo="006">Их после Муза ожив<stress>и</stress>ла:</line>
# Name: Text, dtype: object
# ('Il', nan) 34     <line lineNo="007">Потом Monsieur ее смен<stress>и</stress>л;</line>
# 35     <line lineNo="008">Ребенок был резов, но м<stress>и</stress>л.</line>
# 40     <line lineNo="013">Слегка за шалости бран<stress>и</stress>л,</line>
# 41     <line lineNo="014">И в Летний сад гулять вод<stress>и</stress>л.</line>
# 54     <line lineNo="013">Чего ж вам больше? Свет реш<stress>и</stress>л,</line>
# 55     <line lineNo="014">Что он умен и очень м<stress>и</stress>л.</line>
# 202    <line lineNo="007">С младой Семеновой дел<stress>и</stress>л;</line>
# 203    <line lineNo="008">Там наш Катенин воскрес<stress>и</stress>л</line>
# 303    <line lineNo="010">Пред зеркалами провод<stress>и</stress>л,</line>
# 304    <line lineNo="011">И из уборной выход<stress>и</stress>л</line>
# 365    <line lineNo="002">Я много жизни погуб<stress>и</stress>л!</line>
# 367    <line lineNo="004">Я балы б до сих пор люб<stress>и</stress>л.</line>
# 614    <line lineNo="013">Где я страдал, где я люб<stress>и</stress>л,</line>
# 615    <line lineNo="014">Где сердце я похорон<stress>и</stress>л.</line>
# 715    <line lineNo="002">Умильной лаской наград<stress>и</stress>л</line>
# 717    <line lineNo="004">Кого твой стих боготвор<stress>и</stress>л?"</line>
# Name: Text, dtype: object
# ('O', 'gaJ') 36    <line lineNo="009"> Monsieur l'Abbé, француз уб<stress>о</stress>гой,</line>
# 39    <line lineNo="012">Не докучал моралью стр<stress>о</stress>гой,</line>
# Name: Text, dtype: object
# ('TA', nan) 37     <line lineNo="010">Чтоб не измучилось дит<stress>я</stress>,</line>
# 38     <line lineNo="011">Учил его всему шут<stress>я</stress>,</line>
# 449    <line lineNo="002">И утро в полночь обрат<stress>я</stress>,</line>
# 451    <line lineNo="004">Забав и роскоши дит<stress>я</stress>.</line>
# Name: Text, dtype: object
# ('E', 'žnaJ') 42     <line lineNo="001">Когда же юности мят<stress>е</stress>жной</line>
# 44     <line lineNo="003">Пора надежд и грусти н<stress>е</stress>жной,</line>
# 106    <line lineNo="009">Была наука страсти н<stress>е</stress>жной,</line>
# Name: Text, dtype: object
# ('rA', nan) 43     <line lineNo="002">Пришла Евгению пор<stress>а</stress>,</line>
# 45     <line lineNo="004"> Monsieur прогнали со двор<stress>а</stress>.</line>
# 455    <line lineNo="008">И завтра то же, что вчер<stress>а</stress>.</line>
# 477    <line lineNo="002">Давно бы отыскать пор<stress>а</stress>,</line>
# Name: Text, dtype: object
# ('O', 'Di') 46    <line lineNo="005">Вот мой Онегин на своб<stress>о</stress>де;</line>
# 47    <line lineNo="006">Острижен по последней м<stress>о</stress>де;</line>
# Name: Text, dtype: object
# ('Et', nan) 48     <line lineNo="007">Как dandy лондонской од<stress>е</stress>т—</line>
# 49     <line lineNo="008">И наконец увидел св<stress>е</stress>т.</line>
# 166    <line lineNo="013">Пока недремлющий брег<stress>е</stress>т</line>
# 167    <line lineNo="014">Не прозвонит ему об<stress>е</stress>д.</line>
# 177    <line lineNo="010">И трюфли, роскошь юных л<stress>е</stress>т,</line>
# 178    <line lineNo="011">Французской кухни лучший цв<stress>е</stress>т,</line>
# 183    <line lineNo="002">Залить горячий жир котл<stress>е</stress>т,</line>
# 185    <line lineNo="004">Что новый начался бал<stress>е</stress>т.</line>
# 216    <line lineNo="007">Душой исполненный пол<stress>е</stress>т?</line>
# 217    <line lineNo="008">Иль взор унылый не найд<stress>е</stress>т</line>
# 219    <line lineNo="010">И, устремив на чуждый св<stress>е</stress>т</line>
# 220    <line lineNo="011">Разочарованный лорн<stress>е</stress>т,</line>
# 236    <line lineNo="013">То стан совьет, то разовь<stress>е</stress>т,</line>
# 237    <line lineNo="014">И быстрой ножкой ножку бь<stress>е</stress>т.</line>
# 267    <line lineNo="002">Уединенный кабин<stress>е</stress>т,</line>
# 269    <line lineNo="004">Одет, раздет и вновь од<stress>е</stress>т?</line>
# 278    <line lineNo="013">Все украшало кабин<stress>е</stress>т</line>
# 279    <line lineNo="014">Философа в осьмнадцать л<stress>е</stress>т.</line>
# 314    <line lineNo="007">Но панталоны, фрак, жил<stress>е</stress>т, </line>
# 315    <line lineNo="008">Всех этих слов на русском н<stress>е</stress>т;</line>
# 328    <line lineNo="007">Двойные фонари кар<stress>е</stress>т</line>
# 329    <line lineNo="008">Веселый изливают св<stress>е</stress>т</line>
# 359    <line lineNo="010">За дочерьми смотрите всл<stress>е</stress>д:</line>
# 360    <line lineNo="011">Держите прямо свой лорн<stress>е</stress>т!</line>
# 390    <line lineNo="013">Исчезло счастье юных л<stress>е</stress>т—</line>
# 391    <line lineNo="014">Как на лугах ваш легкой сл<stress>е</stress>д.</line>
# 457    <line lineNo="010">Свободный, в цвете лучших л<stress>е</stress>т,</line>
# 458    <line lineNo="011">Среди блистательных поб<stress>е</stress>д,</line>
# 524    <line lineNo="007">Там скука, там обман иль бр<stress>е</stress>д;</line>
# 525    <line lineNo="008">В том совести, в том смысла н<stress>е</stress>т;</line>
# 552    <line lineNo="007">Того раскаянье грыз<stress>е</stress>т.</line>
# 553    <line lineNo="008">Все это часто прида<stress>е</stress>т</line>
# 695    <line lineNo="010">Что намарал я свой портр<stress>е</stress>т,</line>
# 696    <line lineNo="011">Как Байрон, гордости по<stress>э</stress>т,</line>
# 723    <line lineNo="010">Поэзии священный бр<stress>е</stress>д,</line>
# 724    <line lineNo="011">Петрарке шествуя восл<stress>е</stress>д,</line>
# 737    <line lineNo="010">Я все грущу: но слез уж н<stress>е</stress>т,</line>
# 738    <line lineNo="011">И скоро, скоро бури сл<stress>е</stress>д</line>
# Name: Text, dtype: object
# ('E', 'na') 50    <line lineNo="009">Он по-французски соверш<stress>е</stress>нно</line>
# 53    <line lineNo="012">И кланялся непринужд<stress>е</stress>нно;</line>
# Name: Text, dtype: object
# ('Al', nan) 51     <line lineNo="010">Мог изьясняться и пис<stress>а</stress>л;</line>
# 52     <line lineNo="011">Легко мазурку танцов<stress>а</stress>л,</line>
# 323    <line lineNo="002">Мы лучше поспешим на б<stress>а</stress>л,</line>
# 325    <line lineNo="004">Уж мой Онегин поскак<stress>а</stress>л.</line>
# 387    <line lineNo="010">Давно ль для вас я забыв<stress>а</stress>л</line>
# 388    <line lineNo="011">И жажду славы и похв<stress>а</stress>л,</line>
# 404    <line lineNo="013">На зеркальном паркете з<stress>а</stress>л,</line>
# 405    <line lineNo="014">У моря на граните ск<stress>а</stress>л.</line>
# 636    <line lineNo="007">Стремглав по почте поскак<stress>а</stress>л</line>
# 637    <line lineNo="008">И уж заранее зев<stress>а</stress>л,</line>
# 706    <line lineNo="007">Так я, беспечен, воспев<stress>а</stress>л</line>
# 707    <line lineNo="008">И деву гор, мой иде<stress>а</stress>л,</line>
# 720    <line lineNo="007">Я безотрадно испыт<stress>а</stress>л.</line>
# 721    <line lineNo="008">Блажен, кто с нею сочет<stress>а</stress>л</line>
# Name: Text, dtype: object
# ('O', 'gu') 56     <line lineNo="001">Мы все учились понемн<stress>о</stress>гу</line>
# 58     <line lineNo="003">Так воспитаньем, слава б<stress>о</stress>гу,</line>
# 480    <line lineNo="005">Им овладела понемн<stress>о</stress>гу;</line>
# 481    <line lineNo="006">Он застрелиться, слава б<stress>о</stress>гу,</line>
# 718    <line lineNo="005">И, други, никого, ей б<stress>о</stress>гу!</line>
# 719    <line lineNo="006">Любви безумную трев<stress>о</stress>гу</line>
# Name: Text, dtype: object
# ('UT', nan) 57     <line lineNo="002">Чему-нибудь и как-ниб<stress>у</stress>дь,</line>
# 59     <line lineNo="004">У нас немудрено блесн<stress>у</stress>ть.</line>
# 656    <line lineNo="013">И очень рад, что прежний п<stress>у</stress>ть</line>
# 657    <line lineNo="014">Переменил на что-ниб<stress>у</stress>дь.</line>
# Name: Text, dtype: object
# ('O', 'Gix') 60    <line lineNo="005">Онегин был по мненью мн<stress>о</stress>гих</line>
# 61    <line lineNo="006">(Судей решительных и стр<stress>о</stress>гих)</line>
# Name: Text, dtype: object
# ('Ant', nan) 62     <line lineNo="007">Ученый малый, но пед<stress>а</stress>нт:</line>
# 63     <line lineNo="008">Имел он счастливый тал<stress>а</stress>нт</line>
# 300    <line lineNo="007">В своей одежде был пед<stress>а</stress>нт</line>
# 301    <line lineNo="008">И то, что мы назвали фр<stress>а</stress>нт.</line>
# Name: Text, dtype: object
# ('O', 'Ri') 64     <line lineNo="009">Без принужденья в разгов<stress>о</stress>ре</line>
# 67     <line lineNo="012">Хранить молчанье в важном сп<stress>о</stress>ре,</line>
# 162    <line lineNo="009">Покаместь в утреннем уб<stress>о</stress>ре,</line>
# 165    <line lineNo="012">И там гуляет на прост<stress>о</stress>ре,</line>
# 606    <line lineNo="005">Под ризой бурь, с волнами сп<stress>о</stress>ря,</line>
# 607    <line lineNo="006">По вольному распутью м<stress>о</stress>ря</line>
# Name: Text, dtype: object
# ('kA', nan) 65     <line lineNo="010">Коснуться до всего слегк<stress>а</stress>,</line>
# 66     <line lineNo="011">С ученым видом знаток<stress>а</stress> </line>
# 628    <line lineNo="013">Иль предузнав издалек<stress>а</stress> </line>
# 629    <line lineNo="014">Кончину дяди старик<stress>а</stress>.</line>
# Name: Text, dtype: object
# ('Am', nan) 68     <line lineNo="013">И возбуждать улыбку д<stress>а</stress>м</line>
# 69     <line lineNo="014">Огнем нежданных эпигр<stress>а</stress>мм.</line>
# 239    <line lineNo="002">Идет меж кресел по ног<stress>а</stress>м,</line>
# 241    <line lineNo="004">На ложи незнакомых д<stress>а</stress>м;</line>
# 272    <line lineNo="007">И по Балтическим волн<stress>а</stress>м</line>
# 273    <line lineNo="008">За лес и сало возит н<stress>а</stress>м,</line>
# 345    <line lineNo="010">Летают ножки милых д<stress>а</stress>м;</line>
# 346    <line lineNo="011">По их пленительным след<stress>а</stress>м</line>
# 407    <line lineNo="002">Как я завидовал волн<stress>а</stress>м,</line>
# 409    <line lineNo="004">С любовью лечь к ее ног<stress>а</stress>м!</line>
# 558    <line lineNo="013">И к шутке, с желчью попол<stress>а</stress>м,</line>
# 559    <line lineNo="014">И злости мрачных эпигр<stress>а</stress>м.</line>
# 751    <line lineNo="010">Плоды трудов моих отд<stress>а</stress>м:</line>
# 752    <line lineNo="011">Иди же к невским берег<stress>а</stress>м,</line>
# Name: Text, dtype: object
# ('I', 'Ni') 70     <line lineNo="001">Латынь из моды вышла н<stress>ы</stress>не:</line>
# 72     <line lineNo="003">Он знал довольно по-лат<stress>ы</stress>не,</line>
# 378    <line lineNo="001">Когда ж, и где, в какой пуст<stress>ы</stress>не,</line>
# 380    <line lineNo="003">Ах, ножки, ножки! где вы н<stress>ы</stress>не?</line>
# Name: Text, dtype: object
# ('A', 'Li') 74    <line lineNo="005">Потолковать об Ювен<stress>а</stress>ле,</line>
# Name: Text, dtype: object
# ('A', 'li') 75    <line lineNo="006">В конце письма поставить v<stress>a</stress>le, </line>
# Name: Text, dtype: object
# ('xA', nan) 76    <line lineNo="007">Да помнил, хоть не без грех<stress>а</stress>,</line>
# 77    <line lineNo="008">Из Энеиды два стих<stress>а</stress>.</line>
# Name: Text, dtype: object
# ('O', 'ti') 78    <line lineNo="009">Он рыться не имел ох<stress>о</stress>ты</line>
# 81    <line lineNo="012">Но дней минувших анекд<stress>о</stress>ты</line>
# Name: Text, dtype: object
# ('LI', nan) 79    <line lineNo="010">В хронологической пыл<stress>и</stress> </line>
# 80    <line lineNo="011">Бытописания земл<stress>и</stress>:</line>
# Name: Text, dtype: object
# ('EJ', nan) 82     <line lineNo="013">От Ромула до наших дн<stress>е</stress>й</line>
# 83     <line lineNo="014">Хранил он в памяте сво<stress>е</stress>й.</line>
# 110    <line lineNo="013">В Молдавии, в глуши степ<stress>е</stress>й,</line>
# 111    <line lineNo="014">Вдали Италии сво<stress>е</stress>й.</line>
# 261    <line lineNo="010">Наскуча упряжью сво<stress>е</stress>й,</line>
# 262    <line lineNo="011">И кучера, вокруг огн<stress>е</stress>й,</line>
# 295    <line lineNo="002">И думать о красе ногт<stress>е</stress>й:</line>
# 297    <line lineNo="004">Обычай деспот меж люд<stress>е</stress>й.</line>
# 412    <line lineNo="007">Нет, никогда средь пылких дн<stress>е</stress>й</line>
# 413    <line lineNo="008">Кипящей младости мо<stress>е</stress>й</line>
# 418    <line lineNo="013">Нет, никогда порыв страст<stress>е</stress>й</line>
# 419    <line lineNo="014">Так не терзал души мо<stress>е</stress>й!</line>
# 429    <line lineNo="010">Болтливой лирою сво<stress>е</stress>й;</line>
# 430    <line lineNo="011">Они не стоят ни страст<stress>е</stress>й,</line>
# 530    <line lineNo="013">И полку, с пыльной их семь<stress>е</stress>й,</line>
# 544    <line lineNo="013">Слепой Фортуны и люд<stress>е</stress>й</line>
# 545    <line lineNo="014">На самом утре наших дн<stress>е</stress>й.</line>
# 547    <line lineNo="002">В душе не презирать люд<stress>е</stress>й;</line>
# 549    <line lineNo="004">Призрак невозвратимых дн<stress>е</stress>й:</line>
# 603    <line lineNo="002">Пора, пора!—взываю к н<stress>е</stress>й;</line>
# 605    <line lineNo="004">Маню ветрила корабл<stress>е</stress>й.</line>
# 611    <line lineNo="010">И средь полуденных зыб<stress>е</stress>й,</line>
# 612    <line lineNo="011">Под небом Африки мо<stress>е</stress>й,</line>
# Name: Text, dtype: object
# ('E', 'Ji') 84     <line lineNo="001">Высокой страсти не им<stress>е</stress>я</line>
# 86     <line lineNo="003">Не мог он ямба от хор<stress>е</stress>я,</line>
# 252    <line lineNo="001">Еще амуры, черти, зм<stress>е</stress>и</line>
# 254    <line lineNo="003">Еще усталые лак<stress>е</stress>и</line>
# Name: Text, dtype: object
# ('IT', nan) 85    <line lineNo="002">Для звуков жизни не щад<stress>и</stress>ть,</line>
# 87    <line lineNo="004">Как мы ни бились, отлич<stress>и</stress>ть.</line>
# Name: Text, dtype: object
# ('I', 'ta') 88    <line lineNo="005">Бранил Гомера, Феокр<stress>и</stress>та;</line>
# 89    <line lineNo="006">За то читал Адама См<stress>и</stress>та,</line>
# Name: Text, dtype: object
# ('Om', nan) 90     <line lineNo="007">И был глубокой экон<stress>о</stress>м,</line>
# 91     <line lineNo="008">То есть, умел судить о т<stress>о</stress>м,</line>
# 331    <line lineNo="010">Усеян плошками круг<stress>о</stress>м,</line>
# 332    <line lineNo="011">Блестит великолепный д<stress>о</stress>м;</line>
# 698    <line lineNo="013">Писать поэмы о друг<stress>о</stress>м,</line>
# 699    <line lineNo="014">Как только о себе сам<stress>о</stress>м.</line>
# Name: Text, dtype: object
# ('E', 'Jit') 92    <line lineNo="009">Как государство богат<stress>е</stress>ет,</line>
# 95    <line lineNo="012">Когда простой продукт им<stress>е</stress>ет.</line>
# Name: Text, dtype: object
# ('mU', nan) 93    <line lineNo="010">И чем живет, и почем<stress>у</stress> </line>
# 94    <line lineNo="011">Не нужно золота ем<stress>у</stress>,</line>
# Name: Text, dtype: object
# ('E', 'NiJ') 98     <line lineNo="001">Всего, что знал еще Евг<stress>е</stress>ний,</line>
# 100    <line lineNo="003">Но в чем он истинный был г<stress>е</stress>ний,</line>
# 298    <line lineNo="005">Второй Чадаев, мой Евг<stress>е</stress>ний,</line>
# 299    <line lineNo="006">Боясь ревнивых осужд<stress>е</stress>ний,</line>
# 456    <line lineNo="009">Но был ли счастлив мой Евг<stress>е</stress>ний,</line>
# 459    <line lineNo="012">Среди вседневных наслажд<stress>е</stress>ний?</line>
# 508    <line lineNo="005">И вас покинул мой Евг<stress>е</stress>ний.</line>
# 509    <line lineNo="006">Отступник бурных наслажд<stress>е</stress>ний,</line>
# 574    <line lineNo="001">С душою, полной сожал<stress>е</stress>ний,</line>
# 576    <line lineNo="003">Стоял задумчиво Евг<stress>е</stress>ний,</line>
# Name: Text, dtype: object
# ('Uk', nan) 99     <line lineNo="002">Пересказать мне недос<stress>у</stress>г;</line>
# 101    <line lineNo="004">Что знал он тверже всех на<stress>у</stress>к,</line>
# 135    <line lineNo="010">Подслушать сердца первый зв<stress>у</stress>к,</line>
# 136    <line lineNo="011">Преследовать любовь, и вдр<stress>у</stress>г</line>
# 580    <line lineNo="007">Да дрожек отдаленный ст<stress>у</stress>к</line>
# 581    <line lineNo="008">С Мильонной раздавался вдр<stress>у</stress>г;</line>
# Name: Text, dtype: object
# ('A', 'da') 102    <line lineNo="005">Что было для него измл<stress>а</stress>да</line>
# 103    <line lineNo="006">И труд и мука и отр<stress>а</stress>да,</line>
# 280    <line lineNo="001">Янтарь на трубках Царегр<stress>а</stress>да,</line>
# 282    <line lineNo="003">И, чувств изнеженных отр<stress>а</stress>да,</line>
# Name: Text, dtype: object
# ('EN', nan) 104    <line lineNo="007">Что занимало целый д<stress>е</stress>нь</line>
# 105    <line lineNo="008">Его тоскующую л<stress>е</stress>нь,—</line>
# Name: Text, dtype: object
# ('On', nan) 107    <line lineNo="010">Которую воспел Наз<stress>о</stress>н,</line>
# 108    <line lineNo="011">За что страдальцем кончил <stress>о</stress>н</line>
# 244    <line lineNo="007">Ужасно недоволен <stress>о</stress>н;</line>
# 245    <line lineNo="008">С мужчинами со всех стор<stress>о</stress>н</line>
# 264    <line lineNo="013">А уж Онегин вышел в<stress>о</stress>н;</line>
# 265    <line lineNo="014">Домой одеться едет <stress>о</stress>н.</line>
# 348    <line lineNo="013">И ревом скрыпок заглуш<stress>о</stress>н</line>
# 435    <line lineNo="002">В постелю с бала едет <stress>о</stress>н:</line>
# 485    <line lineNo="010">В гостиных появлялся <stress>о</stress>н;</line>
# 486    <line lineNo="011">Ни сплетни света, ни бост<stress>о</stress>н,</line>
# 491    <line lineNo="002">Всех прежде вас оставил <stress>о</stress>н;</line>
# 493    <line lineNo="004">Довольно скучен высший т<stress>о</stress>н;</line>
# 645    <line lineNo="002">К покойнику со всех стор<stress>о</stress>н</line>
# 647    <line lineNo="004">Охотники до похор<stress>о</stress>н.</line>
# 664    <line lineNo="007">Потом уж наводили с<stress>о</stress>н;</line>
# 665    <line lineNo="008">Потом увидел ясно <stress>о</stress>н,</line>
# 678    <line lineNo="007">И far niente мой зак<stress>о</stress>н.</line>
# Name: Text, dtype: object
# ('E', 'žniJ') 109    <line lineNo="012">Свой век блестящий и мят<stress>е</stress>жный</line>
# Name: Text, dtype: object
# ('E', 'RiT') 112    <line lineNo="001">Как рано мог он лицем<stress>е</stress>рить,</line>
# 114    <line lineNo="003">Разуверять, заставить в<stress>е</stress>рить,</line>
# Name: Text, dtype: object
# ('U', 'šnim') 116    <line lineNo="005">Являться гордым и посл<stress>у</stress>шным,</line>
# 117    <line lineNo="006">Внимательным, иль равнод<stress>у</stress>шным!</line>
# Name: Text, dtype: object
# ('If', nan) 118    <line lineNo="007">Как томно был он молчал<stress>и</stress>в,</line>
# 119    <line lineNo="008">Как пламенно краснореч<stress>и</stress>в,</line>
# Name: Text, dtype: object
# ('E', 'žin') 120    <line lineNo="009">В сердечных письмах как небр<stress>е</stress>жен!</line>
# 123    <line lineNo="012">Как взор его был быстр и н<stress>е</stress>жен,</line>
# Name: Text, dtype: object
# ('OJ', nan) 124    <line lineNo="013">Стыдлив и дерзок, а пор<stress>о</stress>й</line>
# 125    <line lineNo="014">Блистал послушною слез<stress>о</stress>й!</line>
# 152    <line lineNo="013">Всегда довольный сам соб<stress>о</stress>й,</line>
# 153    <line lineNo="014">Своим обедом и жен<stress>о</stress>й.</line>
# 205    <line lineNo="010">Там вывел колкий Шаховск<stress>о</stress>й</line>
# 206    <line lineNo="011">Своих комедий шумный р<stress>о</stress>й,</line>
# 337    <line lineNo="002">Швейцара мимо он стрел<stress>о</stress>й</line>
# 339    <line lineNo="004">Расправил волоса рук<stress>о</stress>й,</line>
# 398    <line lineNo="007">Влечет условною крас<stress>о</stress>й</line>
# 399    <line lineNo="008">Желаний своевольный р<stress>о</stress>й.</line>
# 505    <line lineNo="002">Которых позднею пор<stress>о</stress>й</line>
# 507    <line lineNo="004">По петербургской мостов<stress>о</stress>й,</line>
# 519    <line lineNo="002">Томясь душевной пустот<stress>о</stress>й,</line>
# 521    <line lineNo="004">Себе присвоить ум чуж<stress>о</stress>й;</line>
# 531    <line lineNo="014">Задернул траурной тафт<stress>о</stress>й.</line>
# 572    <line lineNo="013">Так уносились мы мечт<stress>о</stress>й</line>
# 573    <line lineNo="014">К началу жизни молод<stress>о</stress>й.</line>
# 594    <line lineNo="007">Он мне знаком, он мне родн<stress>о</stress>й.</line>
# 595    <line lineNo="008">Ночей Италии злат<stress>о</stress>й</line>
# 597    <line lineNo="010">С венециянкою млад<stress>о</stress>й,</line>
# 598    <line lineNo="011">То говорливой, то нем<stress>о</stress>й,</line>
# 687    <line lineNo="002">Поля! я предан вам душ<stress>о</stress>й.</line>
# 689    <line lineNo="004">Между Онегиным и мн<stress>о</stress>й,</line>
# Name: Text, dtype: object
# ('O', 'vim') 126    <line lineNo="001">Как он умел казаться н<stress>о</stress>вым,</line>
# 128    <line lineNo="003">Пугать отчаяньем гот<stress>о</stress>вым,</line>
# Name: Text, dtype: object
# ('EN', 'Ji') 130    <line lineNo="005">Ловить минуту умил<stress>е</stress>нья,</line>
# 131    <line lineNo="006">Невинных лет предубежд<stress>е</stress>нья</line>
# 386    <line lineNo="009">Роскошное прикоснов<stress>е</stress>нье.</line>
# 389    <line lineNo="012">И край отцов и заточ<stress>е</stress>нье?</line>
# 424    <line lineNo="005">Опять кипит воображ<stress>е</stress>нье,</line>
# 425    <line lineNo="006">Опять ее прикоснов<stress>е</stress>нье</line>
# 714    <line lineNo="001">"Чей взор, волнуя вдохнов<stress>е</stress>нье,</line>
# 716    <line lineNo="003">Твое задумчивое п<stress>е</stress>нье?</line>
# 750    <line lineNo="009">И журналистам на съед<stress>е</stress>нье</line>
# 753    <line lineNo="012">Новорожденное твор<stress>е</stress>нье,</line>
# Name: Text, dtype: object
# ('AN', 'Ji') 134    <line lineNo="009">Молить и требовать призн<stress>а</stress>нья,</line>
# 137    <line lineNo="012">Добиться тайного свид<stress>а</stress>нья...</line>
# 634    <line lineNo="005">Прочтя печальное посл<stress>а</stress>нье,</line>
# 635    <line lineNo="006">Евгений тотчас на свид<stress>а</stress>нье</line>
# Name: Text, dtype: object
# ('NE', nan) 138    <line lineNo="013">И после ей наедин<stress>е</stress> </line>
# 139    <line lineNo="014">Давать уроки в тишин<stress>е</stress>!</line>
# Name: Text, dtype: object
# ('O', 'žiT') 140    <line lineNo="001">Как рано мог уж он трев<stress>о</stress>жить</line>
# 142    <line lineNo="003">Когда ж хотелось уничт<stress>о</stress>жить</line>
# Name: Text, dtype: object
# ('O', 'Vil') 144    <line lineNo="005">Как он язвительно злосл<stress>о</stress>вил!</line>
# 145    <line lineNo="006">Какие сети им гот<stress>о</stress>вил!</line>
# Name: Text, dtype: object
# ('žJA', nan) 146    <line lineNo="007">Но вы, блаженные мужь<stress>я</stress>,</line>
# Name: Text, dtype: object
# ('ZJA', nan) 147    <line lineNo="008">С ним оставались вы друзь<stress>я</stress>:</line>
# 393    <line lineNo="002">Прелестны, милые друзь<stress>я</stress>!</line>
# 701    <line lineNo="002">Любви мечтательной друзь<stress>я</stress>.</line>
# 709    <line lineNo="010">Теперь от вас, мои друзь<stress>я</stress>,</line>
# Name: Text, dtype: object
# ('A', 'viJ') 148    <line lineNo="009">Его ласкал супруг лук<stress>а</stress>вый,</line>
# 151    <line lineNo="012">И рогоносец велич<stress>а</stress>вый,</line>
# 204    <line lineNo="009">Корнеля гений велич<stress>а</stress>вый;</line>
# Name: Text, dtype: object
# ('Ik', nan) 149    <line lineNo="010">Фобласа давний учен<stress>и</stress>к,</line>
# 150    <line lineNo="011">И недоверчивый стар<stress>и</stress>к,</line>
# 169    <line lineNo="002">"Пади, пади!" раздался кр<stress>и</stress>к;</line>
# 171    <line lineNo="004">Его бобровый воротн<stress>и</stress>к.</line>
# 555    <line lineNo="010">Сперва Онегина яз<stress>ы</stress>к</line>
# 556    <line lineNo="011">Меня смущал; но я прив<stress>ы</stress>к</line>
# Name: Text, dtype: object
# ('E', 'Li') 154    <line lineNo="001">Бывало, он еще в пост<stress>е</stress>ле:</line>
# 156    <line lineNo="003">Что? Приглашенья? В самом д<stress>е</stress>ле,</line>
# 466    <line lineNo="005">Измены утомить усп<stress>е</stress>ли;</line>
# 467    <line lineNo="006">Друзья и дружба надо<stress>е</stress>ли,</line>
# 630    <line lineNo="001">Вдруг получил он в самом д<stress>е</stress>ле</line>
# 632    <line lineNo="003">Что дядя при смерти в пост<stress>е</stress>ле</line>
# Name: Text, dtype: object
# ('Ut', nan) 155    <line lineNo="002">К нему записочки нес<stress>у</stress>т.</line>
# 157    <line lineNo="004">Три дома на вечер зов<stress>у</stress>т:</line>
# Name: Text, dtype: object
# ('A', 'ZNik') 158    <line lineNo="005">Там будет бал, там детский пр<stress>а</stress>здник.</line>
# 159    <line lineNo="006">Куда ж поскачет мой прок<stress>а</stress>зник?</line>
# Name: Text, dtype: object
# ('vnO', nan) 160    <line lineNo="007">С кого начнет он? Все равн<stress>о</stress>:</line>
# Name: Text, dtype: object
# ('nO', nan) 161    <line lineNo="008">Везде поспеть немудрен<stress>о</stress>.</line>
# Name: Text, dtype: object
# ('Ar', nan) 163    <line lineNo="010">Надев широкий болив<stress>а</stress>р, </line>
# 164    <line lineNo="011">Онегин едет на бульв<stress>а</stress>р,</line>
# Name: Text, dtype: object
# ('I', 'TSi') 168    <line lineNo="001">Уж темно: в санки он сад<stress>и</stress>тся.</line>
# 170    <line lineNo="003">Морозной пылью серебр<stress>и</stress>тся</line>
# Name: Text, dtype: object
# ('E', 'Rin') 172    <line lineNo="005">К Talon помчался: он ув<stress>е</stress>рен,</line>
# 173    <line lineNo="006">Что там уж ждет его Кав<stress>е</stress>рин.</line>
# Name: Text, dtype: object
# ('E', 'niJ') 176    <line lineNo="009">Пред ним roast-beef окровавл<stress>е</stress>нный,</line>
# 179    <line lineNo="012">И Стразбурга пирог нетл<stress>е</stress>нный</line>
# 448    <line lineNo="001">Но, шумом бала утомл<stress>е</stress>нный,</line>
# Name: Text, dtype: object
# ('Im', nan) 180    <line lineNo="013">Меж сыром Лимбургским жив<stress>ы</stress>м</line>
# 181    <line lineNo="014">И ананасом золот<stress>ы</stress>м.</line>
# 289    <line lineNo="010">Не мог понять, как важный Гр<stress>и</stress>м</line>
# 290    <line lineNo="011">Смел чистить ногти перед н<stress>и</stress>м,</line>
# 443    <line lineNo="010">Открыты ставни; трубный д<stress>ы</stress>м</line>
# 444    <line lineNo="011">Столбом восходит голуб<stress>ы</stress>м,</line>
# 625    <line lineNo="010">Довольный жребием сво<stress>и</stress>м,</line>
# 626    <line lineNo="011">Наследство предоставил <stress>и</stress>м,</line>
# Name: Text, dtype: object
# ('O', 'Sit') 182    <line lineNo="001">Еще бокалов жажда пр<stress>о</stress>сит</line>
# 184    <line lineNo="003">Но звон брегета им дон<stress>о</stress>сит,</line>
# Name: Text, dtype: object
# ('Is', nan) 188    <line lineNo="007">Очаровательных актр<stress>и</stress>с,</line>
# 189    <line lineNo="008">Почетный гражданин кул<stress>и</stress>с,</line>
# 208    <line lineNo="013">Там, там под сению кул<stress>и</stress>с</line>
# Name: Text, dtype: object
# ('A', 'tru') 190    <line lineNo="009">Онегин полетел к те<stress>а</stress>тру,</line>
# 193    <line lineNo="012">Обшикать Федру, Клеоп<stress>а</stress>тру,</line>
# Name: Text, dtype: object
# ('šA', nan) 191    <line lineNo="010">Где каждый, вольностью дыш<stress>а</stress>,</line>
# Name: Text, dtype: object
# ('At', nan) 192    <line lineNo="011">Готов охлопать entrech<stress>a</stress>t, </line>
# 253    <line lineNo="002">На сцене скачут и шум<stress>я</stress>т;</line>
# 255    <line lineNo="004">На шубах у подъезда сп<stress>я</stress>т;</line>
# 306    <line lineNo="013">Когда, надев мужской нар<stress>я</stress>д,</line>
# 307    <line lineNo="014">Богиня едет в маскар<stress>а</stress>д.</line>
# 309    <line lineNo="002">Заняв ваш любопытный взгл<stress>я</stress>д,</line>
# 311    <line lineNo="004">Здесь описать его нар<stress>я</stress>д;</line>
# 370    <line lineNo="007">И дам обдуманный нар<stress>я</stress>д;</line>
# 371    <line lineNo="008">Люблю их ножки; только вр<stress>я</stress>д</line>
# 631    <line lineNo="002">От управителя докл<stress>а</stress>д,</line>
# 633    <line lineNo="004">И с ним проститься был бы р<stress>а</stress>д.</line>
# Name: Text, dtype: object
# ('vO', nan) 194    <line lineNo="013">Моину вызвать (для тог<stress>о</stress>,</line>
# 195    <line lineNo="014">Чтоб только слышали ег<stress>о</stress>).</line>
# 488    <line lineNo="013">Ничто не трогало ег<stress>о</stress>,</line>
# 489    <line lineNo="014">Не замечал он ничег<stress>о</stress>.</line>
# 513    <line lineNo="010">Ему был тошен; ничег<stress>о</stress> </line>
# 514    <line lineNo="011">Не вышло из пера ег<stress>о</stress>,</line>
# Name: Text, dtype: object
# ('O', 'di') 196    <line lineNo="001">Волшебный край! там в стары г<stress>о</stress>ды,</line>
# 198    <line lineNo="003">Блистал Фонвизин, друг своб<stress>о</stress>ды,</line>
# 602    <line lineNo="001">Придет ли час моей своб<stress>о</stress>ды?</line>
# 604    <line lineNo="003">Брожу над морем, жду пог<stress>о</stress>ды,</line>
# 680    <line lineNo="009">Для сладкой неги и своб<stress>о</stress>ды:</line>
# 683    <line lineNo="012">Не так ли я в былые г<stress>о</stress>ды</line>
# Name: Text, dtype: object
# ('In', nan) 197    <line lineNo="002">Сатиры смелый властел<stress>и</stress>н,</line>
# 199    <line lineNo="004">И переимчивый Княжн<stress>и</stress>н;</line>
# 502    <line lineNo="013">Так неприступны для мужч<stress>и</stress>н,</line>
# 503    <line lineNo="014">Что вид их уж рождает спл<stress>и</stress>н. </line>
# Name: Text, dtype: object
# ('A', 'Ni') 200    <line lineNo="005">Там Озеров невольны д<stress>а</stress>ни</line>
# Name: Text, dtype: object
# ('A', 'NiJ') 201    <line lineNo="006">Народных слез, рукоплеск<stress>а</stress>ний</line>
# 350    <line lineNo="001">Во дни веселий и жел<stress>а</stress>ний</line>
# 352    <line lineNo="003">Верней нет места для призн<stress>а</stress>ний</line>
# 550    <line lineNo="005">Тому уж нет очаров<stress>а</stress>ний,</line>
# 551    <line lineNo="006">Того змия воспомин<stress>а</stress>ний,</line>
# Name: Text, dtype: object
# ('A', 'vaJ') 207    <line lineNo="012">Там и Дидло венчался сл<stress>а</stress>вой,</line>
# Name: Text, dtype: object
# ('IS', nan) 209    <line lineNo="014">Младые дни мои несл<stress>и</stress>сь.</line>
# 650    <line lineNo="007">И после важно разошл<stress>и</stress>сь,</line>
# 651    <line lineNo="008">Как будто делом занял<stress>и</stress>сь.</line>
# Name: Text, dtype: object
# ('E', 'vi') 210    <line lineNo="001">Мои богини! что вы? гд<stress>е</stress> вы?</line>
# 212    <line lineNo="003">Все те же ль вы? другие ль д<stress>е</stress>вы,</line>
# Name: Text, dtype: object
# ('O', 'ri') 214    <line lineNo="005">Услышу ль вновь я ваши х<stress>о</stress>ры?</line>
# 215    <line lineNo="006">Узрю ли русской Терпсих<stress>о</stress>ры</line>
# 344    <line lineNo="009">Бренчат кавалергарда шп<stress>о</stress>ры;</line>
# 347    <line lineNo="012">Летают пламенные вз<stress>о</stress>ры,</line>
# 392    <line lineNo="001">Дианы грудь, ланиты Фл<stress>о</stress>ры</line>
# 394    <line lineNo="003">Однако ножка Терпсих<stress>о</stress>ры</line>
# Name: Text, dtype: object
# ('U', 'šnaJ') 218    <line lineNo="009">Знакомых лиц на сцене ск<stress>у</stress>чной,</line>
# Name: Text, dtype: object
# ('U', 'šniJ') 221    <line lineNo="012">Веселья зритель равнод<stress>у</stress>шный,</line>
# Name: Text, dtype: object
# ('E', 'Qut') 224    <line lineNo="001">Театр уж полон; ложи бл<stress>е</stress>щут;</line>
# 226    <line lineNo="003">В райке нетерпеливо пл<stress>е</stress>щут,</line>
# Name: Text, dtype: object
# ('It', nan) 225    <line lineNo="002">Партер и кресла, все кип<stress>и</stress>т;</line>
# 227    <line lineNo="004">И, взвившись, занавес шум<stress>и</stress>т.</line>
# 233    <line lineNo="010">Другою медленно круж<stress>и</stress>т,</line>
# 234    <line lineNo="011">И вдруг прыжок, и вдруг лет<stress>и</stress>т,</line>
# 415    <line lineNo="010">Лобзать уста младых Арм<stress>и</stress>д,</line>
# 416    <line lineNo="011">Иль розы пламенных лан<stress>и</stress>т,</line>
# 440    <line lineNo="007">С кувшином охтинка спеш<stress>и</stress>т,</line>
# 441    <line lineNo="008">Под ней снег утренний хруст<stress>и</stress>т.</line>
# 575    <line lineNo="002">И опершися на гран<stress>и</stress>т,</line>
# 577    <line lineNo="004">Как описал себя Пи<stress>и</stress>т.</line>
# Name: Text, dtype: object
# ('U', 'šna') 228    <line lineNo="005">Блистательна, полувозд<stress>у</stress>шна,</line>
# 229    <line lineNo="006">Смычку волшебному посл<stress>у</stress>шна,</line>
# Name: Text, dtype: object
# ('nA', nan) 230    <line lineNo="007">Толпою нимф окружен<stress>а</stress>,</line>
# 231    <line lineNo="008">Стоит Истомина; он<stress>а</stress>,</line>
# 527    <line lineNo="010">И устарела старин<stress>а</stress>,</line>
# 670    <line lineNo="013">И бегала за ним он<stress>а</stress>,</line>
# 671    <line lineNo="014">Как тень, иль верная жен<stress>а</stress>.</line>
# Name: Text, dtype: object
# ('O', 'la') 232    <line lineNo="009">Одной ногой касаясь п<stress>о</stress>ла,</line>
# 235    <line lineNo="012">Летит, как пух от уст Э<stress>о</stress>ла;</line>
# Name: Text, dtype: object
# ('O', 'Dit') 238    <line lineNo="001">Все хлопает. Онегин вх<stress>о</stress>дит,</line>
# 240    <line lineNo="003">Двойной лорнет скосясь нав<stress>о</stress>дит</line>
# 330    <line lineNo="009">И радуги на снег нав<stress>о</stress>дят;</line>
# 333    <line lineNo="012">По цельным окнам тени х<stress>о</stress>дят,</line>
# Name: Text, dtype: object
# ('O', 'ram') 242    <line lineNo="005">Все ярусы окинул вз<stress>о</stress>ром,</line>
# 243    <line lineNo="006">Все видел: лицами, уб<stress>о</stress>ром</line>
# Name: Text, dtype: object
# ('E', 'nu') 246    <line lineNo="009">Раскланялся, потом на сц<stress>е</stress>ну</line>
# 249    <line lineNo="012">И молвил: "всех пора на см<stress>е</stress>ну;</line>
# Name: Text, dtype: object
# ('Ul', nan) 247    <line lineNo="010">В большом рассеяньи взглян<stress>у</stress>л,</line>
# 248    <line lineNo="011">Отворотился—и зевн<stress>у</stress>л.</line>
# Name: Text, dtype: object
# ('El', nan) 250    <line lineNo="013">Балеты долго я терп<stress>е</stress>л,</line>
# 251    <line lineNo="014">Но и Дидло мне надо<stress>е</stress>л".</line>
# 482    <line lineNo="007">Попробовать не захот<stress>е</stress>л;</line>
# 483    <line lineNo="008">Но к жизни вовсе охлад<stress>е</stress>л.</line>
# Name: Text, dtype: object
# ('O', 'paT') 256    <line lineNo="005">Еще не перестали т<stress>о</stress>пать,</line>
# 257    <line lineNo="006">Сморкаться, кашлять, шикать, хл<stress>о</stress>пать;</line>
# Name: Text, dtype: object
# ('tRI', nan) 258    <line lineNo="007">Еще снаружи и внутр<stress>и</stress> </line>
# Name: Text, dtype: object
# ('RI', nan) 259    <line lineNo="008">Везде блистают фонар<stress>и</stress>;</line>
# Name: Text, dtype: object
# ('O', 'Ni') 260    <line lineNo="009">Еще, прозябнув, бьются к<stress>о</stress>ни,</line>
# 263    <line lineNo="012">Бранят господ и бьют в лад<stress>о</stress>ни:</line>
# Name: Text, dtype: object
# ('Er', 'naJ') 266    <line lineNo="001">Изображу ль в картине в<stress>е</stress>рной</line>
# Name: Text, dtype: object
# ('Er', 'niJ') 268    <line lineNo="003">Где мод воспитанник прим<stress>е</stress>рный</line>
# Name: Text, dtype: object
# ('IL', 'naJ') 270    <line lineNo="005">Все, чем для прихоти об<stress>и</stress>льной</line>
# Name: Text, dtype: object
# ('IL', 'niJ') 271    <line lineNo="006">Торгует Лондон щепет<stress>и</stress>льный</line>
# Name: Text, dtype: object
# ('O', 'dniJ') 274    <line lineNo="009">Все, что в Париже вкус гол<stress>о</stress>дный,</line>
# Name: Text, dtype: object
# ('Af', nan) 275    <line lineNo="010">Полезный промысел избр<stress>а</stress>в,</line>
# 276    <line lineNo="011">Изобретает для заб<stress>а</stress>в,</line>
# 292    <line lineNo="013">Защитник вольности и пр<stress>а</stress>в</line>
# 293    <line lineNo="014">В сем случае совсем не пр<stress>а</stress>в.</line>
# 586    <line lineNo="013">Но слаще, средь ночных заб<stress>а</stress>в,</line>
# 587    <line lineNo="014">Напев Торкватовых окт<stress>а</stress>в!</line>
# Name: Text, dtype: object
# ('O', 'dnaJ') 277    <line lineNo="012">Для роскоши, для неги м<stress>о</stress>дной,—</line>
# Name: Text, dtype: object
# ('LE', nan) 281    <line lineNo="002">Фарфор и бронза на стол<stress>е</stress>,</line>
# 283    <line lineNo="004">Духи в граненом хрустал<stress>е</stress>;</line>
# 642    <line lineNo="013">Его нашел уж на стол<stress>е</stress>,</line>
# 643    <line lineNo="014">Как дань готовую земл<stress>е</stress>.</line>
# Name: Text, dtype: object
# ('I', 'Ji') 284    <line lineNo="005">Гребенки, пилочки стальн<stress>ы</stress>е,</line>
# 285    <line lineNo="006">Прямые ножницы, крив<stress>ы</stress>е,</line>
# 504    <line lineNo="001">И вы, красотки молод<stress>ы</stress>е,</line>
# 506    <line lineNo="003">Уносят дрожки удал<stress>ы</stress>е</line>
# 578    <line lineNo="005">Все было тихо; лишь ночн<stress>ы</stress>е</line>
# 579    <line lineNo="006">Перекликались часов<stress>ы</stress>е;</line>
# 610    <line lineNo="009">Мне неприязненной стих<stress>и</stress>и,</line>
# 613    <line lineNo="012">Вздыхать о сумрачной Росс<stress>и</stress>и,</line>
# Name: Text, dtype: object
# ('Of', nan) 286    <line lineNo="007">И щетки тридцати род<stress>о</stress>в</line>
# 287    <line lineNo="008">И для ногтей и для зуб<stress>о</stress>в.</line>
# 334    <line lineNo="013">Мелькают профили гол<stress>о</stress>в</line>
# 335    <line lineNo="014">И дам и модных чудак<stress>о</stress>в.</line>
# 384    <line lineNo="007">Вы не оставили след<stress>о</stress>в:</line>
# 385    <line lineNo="008">Любили мягких вы ковр<stress>о</stress>в</line>
# 401    <line lineNo="010">Под длинной скатертью стол<stress>о</stress>в,</line>
# 402    <line lineNo="011">Весной на мураве луг<stress>о</stress>в,</line>
# 460    <line lineNo="013">Вотще ли был он средь пир<stress>о</stress>в</line>
# 461    <line lineNo="014">Неосторожен и здор<stress>о</stress>в?</line>
# 667    <line lineNo="010">Хоть нет ни улиц, ни дворц<stress>о</stress>в,</line>
# 668    <line lineNo="011">Ни карт, ни балов, ни стих<stress>о</stress>в.</line>
# 734    <line lineNo="007">Близ неоконченных стих<stress>о</stress>в,</line>
# 735    <line lineNo="008">Ни женских ножек, ни гол<stress>о</stress>в;</line>
# Name: Text, dtype: object
# ('O', 'dam') 288    <line lineNo="009">Руссо (замечу мимох<stress>о</stress>дом)</line>
# 291    <line lineNo="012">Красноречивым сумасбр<stress>о</stress>дом.</line>
# Name: Text, dtype: object
# ('E', 'kam') 294    <line lineNo="001">Быть можно дельным челов<stress>е</stress>ком</line>
# 296    <line lineNo="003">К чему бесплодно спорить с в<stress>е</stress>ком?</line>
# Name: Text, dtype: object
# ('E', 'Ri') 302    <line lineNo="009">Он три часа по крайней м<stress>е</stress>ре</line>
# 305    <line lineNo="012">Подобный ветреной Вен<stress>е</stress>ре,</line>
# Name: Text, dtype: object
# ('E', 'tam') 308    <line lineNo="001">В последнем вкусе туал<stress>е</stress>том</line>
# 310    <line lineNo="003">Я мог бы пред ученым св<stress>е</stress>том</line>
# Name: Text, dtype: object
# ('E', 'la') 312    <line lineNo="005">Конечно б это было см<stress>е</stress>ло,</line>
# 313    <line lineNo="006">Описывать мое же д<stress>е</stress>ло:</line>
# Name: Text, dtype: object
# ('A', 'Mi') 316    <line lineNo="009">А вижу я, винюсь пред в<stress>а</stress>ми,</line>
# 319    <line lineNo="012">Иноплеменными слов<stress>а</stress>ми,</line>
# ...
# 408    <line lineNo="003">Бегущим бурной черед<stress>о</stress>ю</line>
# 560    <line lineNo="001">Как часто летнею пор<stress>о</stress>ю,</line>
# 562    <line lineNo="003">Ночное небо над Нев<stress>о</stress>ю,</line>
# 616    <line lineNo="001">Онегин был готов со мн<stress>о</stress>ю</line>
# 618    <line lineNo="003">Но скоро были мы судьб<stress>о</stress>ю</line>
# Name: Text, dtype: object
# ('EN', 'Jim') 414    <line lineNo="009">Я не желал с таким муч<stress>е</stress>ньем</line>
# 417    <line lineNo="012">Иль перси, полные томл<stress>е</stress>ньем;</line>
# Name: Text, dtype: object
# ('E', 'Mi') 420    <line lineNo="001">Мне памятно другое вр<stress>е</stress>мя!</line>
# 422    <line lineNo="003">Держу я счастливое стр<stress>е</stress>мя...</line>
# 532    <line lineNo="001">Условий света свергнув бр<stress>е</stress>мя,</line>
# 534    <line lineNo="003">С ним подружился я в то вр<stress>е</stress>мя.</line>
# Name: Text, dtype: object
# ('Ax', nan) 421    <line lineNo="002">В заветных иногда мечт<stress>а</stress>х</line>
# 423    <line lineNo="004">И ножку чувствую в рук<stress>а</stress>х;</line>
# Name: Text, dtype: object
# ('OF', nan) 426    <line lineNo="007">Зажгло в увядшем сердце кр<stress>о</stress>вь,</line>
# 427    <line lineNo="008">Опять тоска, опять люб<stress>о</stress>вь!..</line>
# 566    <line lineNo="007">Воспомня прежнюю люб<stress>о</stress>вь,</line>
# 567    <line lineNo="008">Чувствительны, беспечны вн<stress>о</stress>вь,</line>
# Name: Text, dtype: object
# ('E', 'nix') 428    <line lineNo="009">Но полно прославлять надм<stress>е</stress>нных</line>
# 431    <line lineNo="012">Ни песен, ими вдохнов<stress>е</stress>нных:</line>
# Name: Text, dtype: object
# ('O', 'niJ') 434    <line lineNo="001">Что ж мой Онегин? Полус<stress>о</stress>нный</line>
# 436    <line lineNo="003">А Петербург неугом<stress>о</stress>нный</line>
# 571    <line lineNo="012">Перенесен колодник с<stress>о</stress>нный,</line>
# Name: Text, dtype: object
# ('O', 'SČik') 438    <line lineNo="005">Встает купец, идет разн<stress>о</stress>счик,</line>
# 439    <line lineNo="006">На биржу тянется изв<stress>о</stress>зчик,</line>
# Name: Text, dtype: object
# ('A', 'tniJ') 442    <line lineNo="009">Проснулся утра шум при<stress>я</stress>тный.</line>
# 445    <line lineNo="012">И хлебник, немец акур<stress>а</stress>тный,</line>
# Name: Text, dtype: object
# ('E', 'naJ') 450    <line lineNo="003">Спокойно спит в тени блаж<stress>е</stress>нной</line>
# Name: Text, dtype: object
# ('O', 'va') 452    <line lineNo="005">Проснется за-полдень, и сн<stress>о</stress>ва</line>
# 453    <line lineNo="006">До утра жизнь его гот<stress>о</stress>ва,</line>
# Name: Text, dtype: object
# ('strA', nan) 454    <line lineNo="007">Однообразна и пестр<stress>а</stress>.</line>
# Name: Text, dtype: object
# ('I', 'Li') 462    <line lineNo="001">Нет: рано чувства в нем ост<stress>ы</stress>ли;</line>
# 464    <line lineNo="003">Красавицы не долго б<stress>ы</stress>ли</line>
# 648    <line lineNo="005">Покойника похорон<stress>и</stress>ли.</line>
# 649    <line lineNo="006">Попы и гости ели, п<stress>и</stress>ли,</line>
# Name: Text, dtype: object
# ('Um', nan) 463    <line lineNo="002">Ему наскучил света ш<stress>у</stress>м;</line>
# 465    <line lineNo="004">Предмет его привычных д<stress>у</stress>м;</line>
# 538    <line lineNo="007">И резкий, охлажденный <stress>у</stress>м.</line>
# 539    <line lineNo="008">Я был озлоблен, он угр<stress>ю</stress>м;</line>
# 729    <line lineNo="002">И прояснился темный <stress>у</stress>м.</line>
# 731    <line lineNo="004">Волшебных звуков, чувств и д<stress>у</stress>м;</line>
# Name: Text, dtype: object
# ('Il', 'kaJ') 470    <line lineNo="009">Шампанской обливать бут<stress>ы</stress>лкой</line>
# 473    <line lineNo="012">И хоть он был повеса п<stress>ы</stress>лкой,</line>
# Name: Text, dtype: object
# ('vA', nan) 471    <line lineNo="010">И сыпать острые слов<stress>а</stress>,</line>
# 472    <line lineNo="011">Когда болела голов<stress>а</stress>:</line>
# Name: Text, dtype: object
# ('I', 'nu') 476    <line lineNo="001">Недуг, которого прич<stress>и</stress>ну</line>
# 478    <line lineNo="003">Подобный английскому спл<stress>и</stress>ну, </line>
# Name: Text, dtype: object
# ('drA', nan) 479    <line lineNo="004">Короче: русская хандр<stress>а</stress> </line>
# Name: Text, dtype: object
# ('Om', 'niJ') 484    <line lineNo="009">Как Child-Harold, угрюмый, т<stress>о</stress>мный</line>
# 487    <line lineNo="012">Ни милый взгляд, ни вздох нескр<stress>о</stress>мный,</line>
# Name: Text, dtype: object
# ('E', 'ta') 490    <line lineNo="001">Причудницы большого св<stress>е</stress>та!</line>
# 492    <line lineNo="003">И правда то, что в наши л<stress>е</stress>та</line>
# Name: Text, dtype: object
# ('A', 'ma') 494    <line lineNo="005">Хоть, может быть, иная д<stress>а</stress>ма</line>
# 495    <line lineNo="006">Толкует Сея и Бент<stress>а</stress>ма,</line>
# Name: Text, dtype: object
# ('Or', nan) 496    <line lineNo="007">Но вообще их разгов<stress>о</stress>р</line>
# 497    <line lineNo="008">Несносный, хоть невинный взд<stress>о</stress>р;</line>
# Name: Text, dtype: object
# ('O', 'Čni') 498    <line lineNo="009">К тому ж они так непор<stress>о</stress>чны,</line>
# 501    <line lineNo="012">Так осмотрительны, так т<stress>о</stress>чны,</line>
# Name: Text, dtype: object
# ('nI', nan) 499    <line lineNo="010">Так величавы, так умн<stress>ы</stress>,</line>
# 500    <line lineNo="011">Так благочестия полн<stress>ы</stress>,</line>
# 617    <line lineNo="002">Увидеть чуждые стран<stress>ы</stress>;</line>
# 619    <line lineNo="004">На долгой срок разведен<stress>ы</stress>.</line>
# 673    <line lineNo="002">Для деревенской тишин<stress>ы</stress>:</line>
# Name: Text, dtype: object
# ('SA', nan) 510    <line lineNo="007">Онегин дома заперс<stress>я</stress>,</line>
# 511    <line lineNo="008">Зевая, за перо взялс<stress>я</stress>,</line>
# Name: Text, dtype: object
# ('Or', 'niJ') 512    <line lineNo="009">Хотел писать—но труд уп<stress>о</stress>рный</line>
# 515    <line lineNo="012">И не попал он в цех зад<stress>о</stress>рный</line>
# Name: Text, dtype: object
# ('žU', nan) 516    <line lineNo="013">Людей, о коих не суж<stress>у</stress>,</line>
# 517    <line lineNo="014">Затем, что к ним принадлеж<stress>у</stress>.</line>
# Name: Text, dtype: object
# ('EL', 'Ju') 518    <line lineNo="001">И снова, преданный безд<stress>е</stress>лью,</line>
# 520    <line lineNo="003">Уселся он—с похвальной ц<stress>е</stress>лью</line>
# Name: Text, dtype: object
# ('Ol', 'ku') 522    <line lineNo="005">Отрядом книг уставил п<stress>о</stress>лку,</line>
# 523    <line lineNo="006">Читал, читал—а все без т<stress>о</stress>лку:</line>
# Name: Text, dtype: object
# ('I', 'Gi') 526    <line lineNo="009">На всех различные вер<stress>и</stress>ги;</line>
# 529    <line lineNo="012">Как женщин, он оставил кн<stress>и</stress>ги,</line>
# Name: Text, dtype: object
# ('znA', nan) 528    <line lineNo="011">И старым бредит новизн<stress>а</stress>.</line>
# Name: Text, dtype: object
# ('A', 'naST') 536    <line lineNo="005">Мечтам невольная пред<stress>а</stress>нность,</line>
# 537    <line lineNo="006">Неподражательная стр<stress>а</stress>нность</line>
# Name: Text, dtype: object
# ('O', 'ba') 540    <line lineNo="009">Страстей игру мы знали <stress>о</stress>ба:</line>
# 543    <line lineNo="012">Обоих ожидала зл<stress>о</stress>ба</line>
# Name: Text, dtype: object
# ('O', 'žit') 546    <line lineNo="001">Кто жил и мыслил, тот не м<stress>о</stress>жет</line>
# 548    <line lineNo="003">Кто чувствовал, того трев<stress>о</stress>жит</line>
# Name: Text, dtype: object
# ('O', 'ru') 554    <line lineNo="009">Большую прелесть разгов<stress>о</stress>ру.</line>
# 557    <line lineNo="012">К его язвительному сп<stress>о</stress>ру,</line>
# Name: Text, dtype: object
# ('tlO', nan) 561    <line lineNo="002">Когда прозрачно и светл<stress>о</stress> </line>
# Name: Text, dtype: object
# ('klO', nan) 563    <line lineNo="004">И вод веселое стекл<stress>о</stress> </line>
# Name: Text, dtype: object
# ('A', 'ni') 564    <line lineNo="005">Не отражает лик Ди<stress>а</stress>ны,</line>
# 565    <line lineNo="006">Воспомня прежних лет ром<stress>а</stress>ны,</line>
# Name: Text, dtype: object
# ('O', 'naJ') 568    <line lineNo="009">Дыханьем ночи благоскл<stress>о</stress>нной</line>
# Name: Text, dtype: object
# ('mI', nan) 569    <line lineNo="010">Безмолвно упивались м<stress>ы</stress>!</line>
# 570    <line lineNo="011">Как в лес зеленый из тюрьм<stress>ы</stress> </line>
# Name: Text, dtype: object
# ('A', 'Ji') 582    <line lineNo="009">Лишь лодка, веслами мах<stress>а</stress>я,</line>
# 585    <line lineNo="012">Рожок и песня удал<stress>а</stress>я...</line>
# Name: Text, dtype: object
# ('KE', nan) 583    <line lineNo="010">Плыла по дремлющей рек<stress>е</stress>:</line>
# 584    <line lineNo="011">И нас пленяли вдалек<stress>е</stress> </line>
# Name: Text, dtype: object
# ('Ol', 'ni') 588    <line lineNo="001">Адриатические в<stress>о</stress>лны,</line>
# Name: Text, dtype: object
# ('Ol', 'niJ') 590    <line lineNo="003">И, вдохновенья снова п<stress>о</stress>лный,</line>
# Name: Text, dtype: object
# ('O', 'na') 592    <line lineNo="005">Он свят для внуков Аполл<stress>о</stress>на;</line>
# 593    <line lineNo="006">По гордой лире Альби<stress>о</stress>на</line>
# Name: Text, dtype: object
# ('O', 'Li') 596    <line lineNo="009">Я негой наслажусь на в<stress>о</stress>ле</line>
# 599    <line lineNo="012">Плывя в таинственной гонд<stress>о</stress>ле;</line>
# 662    <line lineNo="005">На третий роща, холм и п<stress>о</stress>ле</line>
# 663    <line lineNo="006">Его не занимали б<stress>о</stress>ле;</line>
# Name: Text, dtype: object
# ('JI', nan) 600    <line lineNo="013">С ней обретут уста мо<stress>и</stress> </line>
# Name: Text, dtype: object
# ('bVI', nan) 601    <line lineNo="014">Язык Петрарки и любв<stress>и</stress>.</line>
# Name: Text, dtype: object
# ('Ek', nan) 608    <line lineNo="007">Когда ж начну я вольный б<stress>е</stress>г?</line>
# 609    <line lineNo="008">Пора покинуть скучный бр<stress>е</stress>г</line>
# Name: Text, dtype: object
# ('Al', 'Si') 620    <line lineNo="005">Отец его тогда сконч<stress>а</stress>лся.</line>
# 621    <line lineNo="006">Перед Онегиным собр<stress>а</stress>лся</line>
# Name: Text, dtype: object
# ('Olk', nan) 622    <line lineNo="007">Заимодавцев жадный п<stress>о</stress>лк.</line>
# 623    <line lineNo="008">У каждого свой ум и т<stress>о</stress>лк:</line>
# Name: Text, dtype: object
# ('I', 'Di') 624    <line lineNo="009">Евгений, тяжбы ненав<stress>и</stress>дя,</line>
# 627    <line lineNo="012">Большой потери в том не в<stress>и</stress>дя,</line>
# Name: Text, dtype: object
# ('A', 'Di') 638    <line lineNo="009">Приготовляясь, денег р<stress>а</stress>ди,</line>
# 641    <line lineNo="012">Но, прилетев в деревню д<stress>я</stress>ди,</line>
# Name: Text, dtype: object
# ('An', nan) 639    <line lineNo="010">На вздохи, скуку и обм<stress>а</stress>н</line>
# 640    <line lineNo="011">(И тем я начал мой ром<stress>а</stress>н),</line>
# Name: Text, dtype: object
# ('I', 'TiL') 652    <line lineNo="009">Вот наш Онегин сельской ж<stress>и</stress>тель,</line>
# 655    <line lineNo="012">Порядка враг и расточ<stress>и</stress>тель,</line>
# Name: Text, dtype: object
# ('EL', nan) 653    <line lineNo="010">Заводов, вод, лесов, зем<stress>е</stress>ль</line>
# 654    <line lineNo="011">Хозяин полный, а дос<stress>е</stress>ль</line>
# Name: Text, dtype: object
# ('O', 'vi') 658    <line lineNo="001">Два дня ему казались н<stress>о</stress>вы</line>
# 660    <line lineNo="003">Прохлада сумрачной дубр<stress>о</stress>вы,</line>
# Name: Text, dtype: object
# ('LA', nan) 659    <line lineNo="002">Уединенные пол<stress>я</stress>,</line>
# Name: Text, dtype: object
# ('ČJA', nan) 661    <line lineNo="004">Журчанье тихого ручь<stress>я</stress>;</line>
# Name: Text, dtype: object
# ('A', 'ži') 666    <line lineNo="009">Что и в деревне скука т<stress>а</stress> же,</line>
# 669    <line lineNo="012">Хандра ждала его на стр<stress>а</stress>же,</line>
# Name: Text, dtype: object
# ('Ir', 'naJ') 672    <line lineNo="001">Я был рожден для жизни м<stress>и</stress>рной,</line>
# Name: Text, dtype: object
# ('Ir', 'niJ') 674    <line lineNo="003">В глуши звучнее голос л<stress>и</stress>рный,</line>
# Name: Text, dtype: object
# ('snI', nan) 675    <line lineNo="004">Живее творческие сн<stress>ы</stress>.</line>
# Name: Text, dtype: object
# ('I', 'nim') 676    <line lineNo="005">Досугам посвятясь нев<stress>и</stress>нным,</line>
# 677    <line lineNo="006">Брожу над озером пуст<stress>ы</stress>нным,</line>
# Name: Text, dtype: object
# ('spLU', nan) 681    <line lineNo="010">Читаю мало, долго спл<stress>ю</stress>,</line>
# Name: Text, dtype: object
# ('vLU', nan) 682    <line lineNo="011">Летучей славы не ловл<stress>ю</stress>.</line>
# Name: Text, dtype: object
# ('NI', nan) 684    <line lineNo="013">Провел в бездействии, в тен<stress>и</stress> </line>
# Name: Text, dtype: object
# ('DNI', nan) 685    <line lineNo="014">Мои счастливейшие дн<stress>и</stress>?</line>
# Name: Text, dtype: object
# ('A', 'znaST') 686    <line lineNo="001">Цветы, любовь, деревня, пр<stress>а</stress>здность,</line>
# 688    <line lineNo="003">Всегда я рад заметить р<stress>а</stress>зность</line>
# Name: Text, dtype: object
# ('O', 'žna') 694    <line lineNo="009">Не повторял потом безб<stress>о</stress>жно,</line>
# 697    <line lineNo="012">Как будто нам уж невозм<stress>о</stress>жно</line>
# Name: Text, dtype: object
# ('E', 'ti') 700    <line lineNo="001">Замечу кстати: все по<stress>э</stress>ты—</line>
# 702    <line lineNo="003">Бывало, милые предм<stress>е</stress>ты</line>
# Name: Text, dtype: object
# ('I', 'ra') 708    <line lineNo="009">И пленниц берегов Салг<stress>и</stress>ра.</line>
# 711    <line lineNo="012">"О ком твоя вздыхает л<stress>и</stress>ра?</line>
# Name: Text, dtype: object
# ('Ef', nan) 712    <line lineNo="013">Кому, в толпе ревнивых д<stress>е</stress>в,</line>
# 713    <line lineNo="014">Ты посвятил ее нап<stress>е</stress>в?</line>
# Name: Text, dtype: object
# ('O', 'Jil') 722    <line lineNo="009">Горячку рифм: он тем удв<stress>о</stress>ил</line>
# 725    <line lineNo="012">А муки сердца успок<stress>о</stress>ил,</line>
# Name: Text, dtype: object
# ('Em', nan) 726    <line lineNo="013">Поймал и славу между т<stress>е</stress>м:</line>
# 727    <line lineNo="014">Но я, любя, был глуп и н<stress>е</stress>м.</line>
# Name: Text, dtype: object
# ('U', 'za') 728    <line lineNo="001">Прошла любовь, явилась М<stress>у</stress>за,</line>
# 730    <line lineNo="003">Свободен, вновь ищу со<stress>ю</stress>за</line>
# Name: Text, dtype: object
# ('U', 'Jit') 732    <line lineNo="005">Пишу, и сердце не тоск<stress>у</stress>ет,</line>
# 733    <line lineNo="006">Перо, забывшись, не рис<stress>у</stress>ет,</line>
# Name: Text, dtype: object
# ('I', 'xNit') 736    <line lineNo="009">Погасший пепел уж не всп<stress>ы</stress>хнет,</line>
# 739    <line lineNo="012">В душе моей совсем ут<stress>и</stress>хнет:</line>
# Name: Text, dtype: object
# ('vU', nan) 743    <line lineNo="002">И как героя назов<stress>у</stress>;</line>
# 745    <line lineNo="004">Я кончил первую глав<stress>у</stress>:</line>
# Name: Text, dtype: object
# ('O', 'ga') 746    <line lineNo="005">Пересмотрел все это стр<stress>о</stress>го;</line>
# 747    <line lineNo="006">Противоречний очень мн<stress>о</stress>го,</line>
# Name: Text, dtype: object
# ('ČU', nan) 748    <line lineNo="007">Но их исправить не хоч<stress>у</stress>;</line>
# 749    <line lineNo="008">Цензуре долг свой заплач<stress>у</stress>,</line>
# Name: Text, dtype: object
# ('AN', nan) 754    <line lineNo="013">И заслужи мне славы д<stress>а</stress>нь:</line>
# 755    <line lineNo="014">Кривые толки, шум и бр<stress>а</stress>нь!</line>
# Name: Text, dtype: object

# %%
# FIXME: keep only one C in open masculine, not entire cluster
df.loc[675]
# Out:
# StanzaNo             55
# LineNo               4
# Text                 <line lineNo="004">Живее творческие сн<stress>ы</stress>.</line>
# Phonetic             žiViJi tvarČisKiJi snI
# RhymeWord            snI
# Syllabified          [snI]
# RhymeZone            [snI]
# StrippedRhymeZone    [snI]
# syllcounts           1
# t0                   snI
# t1                   None
# Name: 675, dtype: object

# %% [markdown]
# ## (Resume here)
#
# Todo:
#
# 1. decompose syllables into segments
# 1. decompose segments into phonetic features
# 1. **[learn how to apply ML to rhyme identification]**
# 1. build table of rhymes
# 1. identify imperfect rhymes and describe and analyze at segment and feature level
#
# Each fourteen-line stanza in this poem has the same regular rhyme scheme: **aBaBccDDeFFeGG**. We can use this regularity to find lines that rhyme by matching the line numbers, creating a gold standard that we can use (through cross-validation) to test our (eventual) analytic identification of rhyme.
