# %% [markdown]
# # Counting consonant clusters
#
# To explore possible consonant clusters in Russian, tabulate those in *War and Peace*.

# %% [markdown]
# ## Import packages

# %%
import re
from collections import defaultdict

# %% [markdown]
# ## Constants

# %%
cs = 'бвгджзйклмнпрстфхцчшщ' # consonants
ccpat = re.compile("[" + cs + "]{2,}") # two or more consecutive consonants

# %% [markdown]
# ## Data

# %%
with open("voina-i-mir.txt") as f: # read in all of War and Peace
    text = f.read()
text = re.sub(r"\s+", " ", text.lower()) # whitespace and case normalize

# %% [markdown]
# ## Count occurrences of each type of consonant cluster

# %%
ccs = ccpat.findall(text) # all consonant clusters (292016)
ccdict = defaultdict(int)
for i in ccs:
    ccdict[i] = ccdict[i] + 1
print("There are", len(ccdict), "unique clusters in the text")
# Out:
# There are 616 unique clusters in the text

# %% [markdown]
# ## Sort and print results

# %%
sorted_ccdict = sorted(ccdict.items(), key = lambda x: len(x[0]), reverse=True)
sorted_ccdict[:10]
for i in reversed(range(1, max([len(str(i)) for i in sorted_ccdict[0]]) + 1)):
    hits = [item[0] for item in sorted_ccdict if len(item[0]) == i]
    print("\nThere are", len(hits), "unique consonant clusters of", i, "letters:", end=" ")
    print([sorted(hits, key=lambda x: x[0])][0])
# Out:
# There are 3 unique consonant clusters of 5 letters: ['дрств', 'нтств', 'рптск']
#
# There are 60 unique consonant clusters of 4 letters: ['бств', 'бстр', 'вств', 'встр', 'взгл', 'вскр', 'вспр', 'вспл', 'вздр', 'всхл', 'взбр', 'врбн', 'вздв', 'врск', 'всхр', 'гств', 'дств', 'дстр', 'дтск', 'жств', 'здрж', 'йств', 'ймск', 'йнск', 'йхшт', 'ккск', 'мств', 'нстр', 'нств', 'нтск', 'ндшт', 'ндск', 'нстк', 'нтрб', 'нскр', 'рств', 'ргск', 'рнск', 'рстн', 'рррр', 'рдск', 'рщвл', 'рстг', 'рбск', 'рмск', 'ртсг', 'ствл', 'сстр', 'сств', 'сспр', 'сткл', 'стск', 'стпл', 'тств', 'тмст', 'тстр', 'тпрр', 'фств', 'шпрш', 'шшшш']
#
# There are 248 unique consonant clusters of 3 letters: ['бст', 'бшл', 'бхв', 'бск', 'бгл', 'вск', 'вдр', 'всп', 'вст', 'всл', 'втр', 'взд', 'взм', 'взл', 'впр', 'взр', 'взв', 'впл', 'вкн', 'взб', 'вгл', 'вдв', 'вбл', 'взн', 'всх', 'взг', 'всм', 'вкл', 'вкр', 'гср', 'гсб', 'гск', 'дст', 'дхв', 'дск', 'дтв', 'дпр', 'дпл', 'дкр', 'дтр', 'двк', 'дсв', 'дсм', 'дгр', 'дсл', 'дзн', 'дкл', 'двл', 'дшт', 'ддр', 'жск', 'ждл', 'жгл', 'здн', 'здр', 'зск', 'звр', 'згл', 'згн', 'здв', 'ззв', 'звл', 'збр', 'здк', 'знр', 'ззр', 'здц', 'згр', 'йск', 'йст', 'йтр', 'йнв', 'ймл', 'йшт', 'йпц', 'йдн', 'ктр', 'кст', 'ксп', 'ксг', 'ктн', 'кск', 'лст', 'лжн', 'лкн', 'лнц', 'лчн', 'лкл', 'лтл', 'лзл', 'лвн', 'лдн', 'лчк', 'лвк', 'лзк', 'лкш', 'лбн', 'лбц', 'лкм', 'мпр', 'мгн', 'мгл', 'мск', 'мпл', 'мшт', 'мкн', 'мпф', 'мст', 'ммл', 'мпс', 'нск', 'нкт', 'нгл', 'ндр', 'нтр', 'нтн', 'нтк', 'нгв', 'нсп', 'нцл', 'нбр', 'ншт', 'нст', 'нгр', 'ндн', 'нсф', 'нтм', 'нкс', 'ндц', 'нтц', 'нтл', 'ндб', 'нкп', 'нцм', 'нфр', 'нгт', 'нкц', 'пск', 'прш', 'прж', 'птв', 'ржк', 'ртн', 'рсп', 'рзн', 'рхн', 'рск', 'ркн', 'рчл', 'рдц', 'рвн', 'ртр', 'ршк', 'рбл', 'ртв', 'рст', 'рдн', 'рзк', 'ртф', 'ркв', 'ргн', 'рцг', 'ртк', 'ржд', 'ршт', 'ршп', 'ршр', 'рмл', 'рсд', 'рзл', 'рзш', 'ргл', 'ргс', 'рчм', 'рмф', 'ркл', 'рмщ', 'рпр', 'ргц', 'ржн', 'ртл', 'ршн', 'ргш', 'ств', 'скв', 'стр', 'спр', 'сск', 'стн', 'стк', 'скр', 'скл', 'стл', 'сст', 'спл', 'стб', 'схв', 'сдв', 'ссч', 'ссм', 'стс', 'сбр', 'ссл', 'сбл', 'сгр', 'сфр', 'ссв', 'ссн', 'скн', 'сдр', 'стз', 'сцв', 'ссп', 'стф', 'скг', 'стг', 'спб', 'сср', 'счл', 'ткр', 'тск', 'тст', 'твл', 'тпр', 'тсч', 'ткл', 'тхл', 'тбр', 'твр', 'ткн', 'тпл', 'тсд', 'тср', 'тшт', 'тбл', 'ттр', 'тсл', 'тзв', 'тфр', 'тцв', 'ттл', 'фкр', 'фск', 'хдн', 'хск', 'чтм', 'штр', 'шск']
#
# There are 305 unique consonant clusters of 2 letters: ['бр', 'бл', 'бк', 'бз', 'бщ', 'бм', 'бб', 'бн', 'бв', 'бх', 'бд', 'бж', 'бч', 'бг', 'бт', 'бс', 'бц', 'бш', 'вл', 'вн', 'вс', 'вр', 'вм', 'вт', 'вш', 'вп', 'вз', 'вд', 'вк', 'вх', 'вв', 'вг', 'вц', 'вч', 'вб', 'вщ', 'вж', 'гг', 'гр', 'гл', 'гд', 'гв', 'гч', 'гк', 'гн', 'гм', 'гт', 'гс', 'гш', 'гж', 'гз', 'дс', 'дг', 'дш', 'дк', 'дн', 'дд', 'дл', 'дв', 'дц', 'др', 'дт', 'дх', 'дч', 'дм', 'дб', 'дж', 'дп', 'дз', 'дф', 'дщ', 'жн', 'жд', 'жк', 'жч', 'жм', 'жб', 'жл', 'жж', 'жг', 'жр', 'зд', 'зм', 'зн', 'зв', 'зр', 'зл', 'зб', 'зг', 'зж', 'зк', 'зш', 'зч', 'зт', 'зц', 'зз', 'зх', 'йн', 'йт', 'йл', 'йш', 'йц', 'йм', 'йч', 'йд', 'йк', 'йс', 'йб', 'йр', 'йщ', 'йв', 'йх', 'йф', 'йз', 'кр', 'кт', 'кл', 'кц', 'кв', 'кн', 'кк', 'кс', 'кд', 'кж', 'кз', 'кш', 'кч', 'кх', 'км', 'кг', 'лн', 'лл', 'лк', 'лс', 'лж', 'лч', 'лг', 'лп', 'лт', 'лф', 'лд', 'лб', 'лщ', 'лв', 'лм', 'лз', 'лш', 'лх', 'лц', 'мк', 'мп', 'мн', 'мм', 'мч', 'мр', 'мс', 'мф', 'мл', 'мт', 'мз', 'мц', 'мб', 'мш', 'мщ', 'мг', 'мв', 'нн', 'нг', 'нд', 'нт', 'нц', 'нр', 'нч', 'нб', 'нк', 'нм', 'нс', 'нщ', 'нл', 'нз', 'нш', 'нв', 'нф', 'нп', 'нж', 'нх', 'пр', 'пн', 'пп', 'пл', 'пт', 'пч', 'пк', 'пс', 'пц', 'пш', 'пщ', 'пф', 'пг', 'рс', 'рг', 'рт', 'рд', 'рв', 'рк', 'рр', 'рф', 'рж', 'рн', 'рч', 'рщ', 'рб', 'рш', 'рх', 'рл', 'рц', 'рп', 'рм', 'рз', 'сн', 'ст', 'сс', 'сл', 'св', 'ск', 'сп', 'см', 'сд', 'сж', 'сч', 'сш', 'ср', 'сх', 'сц', 'сг', 'сб', 'сф', 'сз', 'сщ', 'тр', 'тд', 'тс', 'тн', 'тк', 'тв', 'тл', 'тм', 'тж', 'тц', 'тх', 'тч', 'тз', 'тп', 'тт', 'тщ', 'тг', 'тб', 'тф', 'тш', 'фр', 'фф', 'фл', 'фт', 'фс', 'фм', 'фн', 'фч', 'фг', 'хр', 'хх', 'хс', 'хв', 'хн', 'хл', 'хм', 'хт', 'хп', 'хш', 'хч', 'хг', 'цв', 'цк', 'цн', 'цм', 'чт', 'чк', 'чш', 'чн', 'чр', 'чл', 'чм', 'чв', 'чч', 'шл', 'шм', 'шк', 'шн', 'шп', 'шт', 'шв', 'шр', 'шц', 'шс', 'щн', 'щр']
#
# There are 0 unique consonant clusters of 1 letters: []
